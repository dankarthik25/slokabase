# %%
from slokabase.WebScrapGreen import *
import os
from slokabase.SqliteModel import get_create_table_query, get_insert_query, get_read_query, get_update_query, get_delete_query
from slokabase.SqliteModel import SqliteModel
from slokabase.hindi2english import hindi2iast 
from bs4 import BeautifulSoup
import requests

# %%
db_name = 'dictionary.db'
db_path = os.path.join(os.getcwd(),db_name)
DictonaryWord_sql = SqliteModel(db_path,'DictWord')
DictonaryMeaning_sql = SqliteModel(db_path,'DictMeaning')

db_name = 'slokabase.db'
db_path = os.path.join(os.getcwd(),db_name)
SongIndex_sql = SqliteModel(db_path,'SongIndex')
mySongs_sql = SqliteModel(db_path,'Songs')

# %%
# url = 'https://greenmesg.org/stotras/durga/devi_aparadha_kshamapana_stotram.php'
# url = 'https://greenmesg.org/stotras/annapoorna/annapoorna_stotram.php'
# url = 'https://greenmesg.org/stotras/vishnu/venkatesa_suprabhatam.php'
# url='https://greenmesg.org/stotras/shiva/shiva_tandava_stotram.php'
# url = 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php'
url = 'https://greenmesg.org/stotras/vishnu/venkatesa_suprabhatam.php'

# %% [markdown]
# ##### 1st Step: `DONE` Scrapp song form website

# %%
source = requests.get(url).text
soup = BeautifulSoup(source)
song_name, song_author = get_name_author(soup)
hindi_text       = get_sanskrit_text(soup)
iast_text = hindi2iast(hindi_text)
translation_text = get_translation(soup)

# %%
print(iast_text)
# print(hindi_text)
# print(translation_text)
# print(len(hindi_text.split('\n\n')), len( translation_text.split('\n\n') )  )
# Out:
# kausalyā suprajā rāma pūrvāsandhyā pravartatē |
# uttiṣṭha naraśārdūla karttavyaṁ daivamāhnikam ||1||
#
# uttiṣṭhottiṣṭha govinda uttiṣṭha garuḍadhvaja |
# uttiṣṭha kamalākānta trailokyaṁ maṅgalaṁ kuru ||2||
#
# mātassamastajagatāṁ madhukaiṭabhārēḥ
# vakṣovihāriṇi manoharadivyamūrtē |
# śrīsvāmini śritajanapriyadānaśīlē
# śrīvēṅkaṭēśadayitē tava suprabhātam ||3||
#
# tava suprabhātamaravindalocanē
# bhavatu prasannamukhacandramaṇḍalē |
# vidhiśaṅkarēndravanitābhirarcitē
# vr̥śaśailanāthadayitē dayānidhē ||4||
#
# atryādisaptaṛṣayassamupāsya sandhyāṁ
# ākāśasindhukamalāni manoharāṇi |
# ādāya pādayugamarcayituṁ prapannāḥ
# śēṣādriśēkharavibho tava suprabhātam ||5||
#
# pañcānanābjabhavaṣaṇmukhavāsavādyāḥ
# traivikramādicaritaṁ vibudhāḥ stuvanti |
# bhāṣāpatiḥ paṭhati vāsaraśuddhimārāt
# śēṣādriśēkharavibho tava suprabhātam ||6||
#
# īṣatpraphullasarasīruhanārikēla
# pūgadrumādisumanoharapālikānām |
# āvāti mandamanilassaha divyagandhaiḥ
# śēṣādriśēkharavibho tava suprabhātam ||7||
#
# unmīlya nētrayugamuttamapañjarasthāḥ
# pātrāvaśiṣṭakadalīphalapāyasāni |
# bhuktvā salīlamatha kēliśukāḥ paṭhanti
# śēṣādriśēkharavibho tava suprabhātam ||8||
#
# tantrīprakarṣamadhurasvanayā vipañcyā
# gāyatyanantacaritaṁ tava nārado’pi |
# bhāṣāsamagramasakr̥tkaracāraramyaṁ
# śēṣādriśēkharavibho tava suprabhātam ||9||
#
# bhr̥ṅgāvalī ca makarandarasānuviddha
# jhaṅkāragītaninadaissaha sēvanāya |
# niryātyupāntasarasīkamalodarēbhyaḥ
# śēṣādriśēkharavibho tava suprabhātam ||10||
#
# yoṣāgaṇēna varadadhni vimathyamānē
# ghoṣālayēṣu dadhimanthanatīvraghoṣāḥ |
# roṣātkaliṁ vidadhatē kakubhaśca kumbhāḥ
# śēṣādriśēkharavibho tava suprabhātam ||11||
#
# padmēśamitraśatapatragatālivargāḥ
# hartuṁ śriyaṁ kuvalayasya nijāṅgalakṣmyā |
# bhērīninādamiva bibhrati tīvranādaṁ
# śēṣādriśēkharavibho tava suprabhātam ||12||
#
# śrīmannabhīṣṭavaradākhilalokabandho
# śrīśrīnivāsa jagadēkadayaikasindho |
# śrīdēvatāgr̥habhujāntaradivyamūrtē
# śrīvēṅkaṭācalapatē tava suprabhātam ||13||
#
# śrīsvāmipuṣkariṇikāplavanirmalāṅgāḥ
# śrēyo’rthino haraviriñcasanandanādyāḥ |
# dvārē vasanti varavētrahatottamāṅgāḥ
# śrīvēṅkaṭācalapatē tava suprabhātam ||14||
#
# śrīśēṣaśaila garuḍācalavēṅkaṭādri
# nārāyaṇādri vr̥ṣabhādrivr̥ṣādri mukhyām |
# ākhyāṁ tvadīyavasatēraniśaṁ vadanti
# śrīvēṅkaṭācalapatē tava suprabhātam ||15||
#
# sēvāparāśśivasurēśakr̥śānudharma
# rakṣo’mbunātha pavamāna dhanādināthāḥ |
# baddhāñjali pravilasannijaśīrṣa dēśāḥ
# śrīvēṅkaṭācalapatē tava suprabhātam ||16||
#
# dhāṭīṣu tē vihagarāja mr̥gādhirāja
# nāgādhirāja gajarāja hayādhirājāḥ |
# svasvādhikāra mahimādhikamarthayantē
# śrīvēṅkaṭācalapatē tava suprabhātam ||17||
#
# sūryēndu bhauma budha vākpati kāvyasauri
# svarbhānu kētu diviṣatpariṣatpradhānāḥ |
# tvaddāsa dāsa caramāvadhi dāsadāsāḥ
# śrīvēṅkaṭācalapatē tava suprabhātam ||18||
#
# tvatpādadhūli bharitasphuritottamāṅgāḥ
# svargāpavarga nirapēkṣa nijāntaraṅgāḥ |
# kalpāgamākalanayākulatāṁ labhantē
# śrīvēṅkaṭācalapatē tava suprabhātam ||19||
#
# tvadgopurāgraśikharāṇi nirīkṣamāṇāḥ
# svargāpavargapadavīṁ paramāṁ śrayantaḥ |
# martyā manuṣyabhuvanē matimāśrayantē
# śrīvēṅkaṭācalapatē tava suprabhātam ||20||
#
# śrībhūmināyaka dayādiguṇāmr̥tābdhē
# dēvādhidēva jagadēkaśaraṇyamūrtē |
# śrīmannanantagaruḍādibhirarcitāṅghrē
# śrīvēṅkaṭācalapatē tava suprabhātam ||21||
#
# śrīpadmanābha puruṣottama vāsudēva
# vaikuṇṭha mādhava janārdana cakrapāṇē |
# śrīvatsacihna śaraṇāgatapārijāta
# śrīvēṅkaṭācalapatē tava suprabhātam ||22||
#
# kandarpadarpahara sundara divyamūrtē
# kāntākucāmburuha kuṭamala loladr̥ṣṭē |
# kalyāṇanirmalaguṇākara divyakīrtē
# śrīvēṅkaṭācalapatē tava suprabhātam ||23||
#
# mīnākr̥tē kamaṭha kola nr̥siṁha varṇin
# svāmin paraśvathatapodhana rāmacandra|
# śēṣāṁśarāma yadunandana kalkirūpa
# śrīvēṅkaṭācalapatē tava suprabhātam ||24||
#
# elā lavaṅga ghanasārasugandhitīrthaṁ
# divyaṁ viyatsariti hēmaghaṭēṣu pūrṇam |
# dhr̥tvā’dya vaidika śikhāmaṇayaḥ prahr̥ṣṭāḥ
# tiṣṭhanti vēṅkaṭapatē tava suprabhātam ||25||
#
# bhāsvānudēti vikacāni saroruhāṇi
# sampūrayanti ninadaiḥ kakubho vihaṅgāḥ |
# śrīvaiṣṇavāssatatamarthitamaṅgalāstē
# dhāmāśrayanti tava vēṅkaṭa suprabhātam ||26||
#
# brahmādayassuravarāssamaharṣayastē
# santassanandanamukhāstavatha yogivaryāḥ |
# dhāmāntikē tava hi maṅgalavastuhastāḥ
# śrīvēṅkaṭācalapatē tava suprabhātam ||27||
#
# lakṣmīnivāsa niravadyaguṇaikasindho
# saṁsāra sāgara samuttaraṇaikasēto |
# vēdāntavēdyanijavaibhava bhaktabhogya
# śrīvēṅkaṭācalapatē tava suprabhātam ||28||
#
# itthaṁ vr̥ṣācalapatēriha suprabhātaṁ
# yē mānavāḥ pratidinaṁ paṭhituṁ pravr̥ttāḥ |
# tēṣāṁ prabhātasamayē smr̥tiraṅgabhājāṁ
# prajñāṁ parārthasulabhāṁ paramāṁ prasūtē ||29||

# %% [markdown]
# ##### 2st Step: `DONE` create new song[with out synonyms] in slokabase.db

# %%
# SongIndex_sql.create_entry(**song_info)
song_info = {}
song_info['song_name'] = song_name# +'1' # 'My Dasavatara Stotram'
song_info['song_short_name'] = song_info['song_name'] .replace(" ","") # 'MyDasaVatStot'
song_info['sloka_statues'] = 1
song_info['division_no'] = 0
song_info['total_slokas'] = len(hindi_text.split('\n\n'))
# song_info['groups']
# song_info['devotion_god']
if song_author is not None:
    song_info['author']= song_author 
# song_info['describtion']=  
song_info['other_links '] = url
print(song_info)
# Out:
# {'song_name': 'Dakshinamurthy Stotram', 'song_short_name': 'DakshinamurthyStotram', 'sloka_statues': 1, 'division_no': 0, 'total_slokas': 19, 'author': 'Sri Adi Shankaracharya', 'other_links ': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php'}

# %%
mysong_idx=73
# song_info =
# song_idx = 
song_info =SongIndex_sql.read_entry( song_idx=mysong_idx)[0] # >>> 5
print(song_info)
# Out:
# {'song_idx': 73, 'song_name': 'Sri Venkatesa Suprabhatam 2', 'song_short_name': 'SriVenkatesaSuprabhatam2', 'sloka_statues': 1, 'division': None, 'division_no': 0, 'total_slokas': 29, 'groups': None, 'devotion_god': 'vishnu', 'author': 'Prathivadhi Bhayankaram Aṇṇan ', 'describtion': ' ', 'other_links': ' https://en.wikipedia.org/wiki/Prathivadhi_Bhayankaram_Annangaracharya\nhttps://greenmesg.org/stotras/vishnu/venkatesa_suprabhatam.php'}

# %%
if len(SongIndex_sql.read_entry(**song_info)) ==0:
    SongIndex_sql.create_entry(**song_info)
    print('Created new song entry in songindex:')
    
song_idx = SongIndex_sql.read_entry( *['song_idx'], **song_info)[0]['song_idx'] # >>> 5
print(SongIndex_sql.read_entry( *['song_idx'], **song_info))
# Out:
# Exception: no such column: None
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 if len(SongIndex_sql.read_entry(**song_info)) ==0:
#       2     SongIndex_sql.create_entry(**song_info)
#       3     print('Created new song entry in songindex:')
#
# File /media/karthik/myVolume/workspace/workspace_vedabase/slokabase/SqliteModel.py:212, in SqliteModel.read_entry(self, *args, **kwargs)
#     210 finally:
#     211     self.db_cursor.close()
# --> 212 return data
#
# UnboundLocalError: cannot access local variable 'data' where it is not associated with a value

# %%
song = dict()
song['sloka_eng'] = iast_text
song['sloka_hindi'] = hindi_text
song['translation'] = translation_text
# print(song)

# %%
mysong = dict()
# mySongs_sql = SqliteModel(db_path,'Songs')
mysong ['song_idx'] = SongIndex_sql.read_entry(*['song_idx'], **song_info)[0]['song_idx']

list_sloka = song['sloka_eng'].split('\n\n')
for idx, sloka in enumerate(list_sloka):
    mysong['slokas_no']   = idx+1
    mysong['sloka_eng']   = sloka.strip()
    print(f"[sloka_eng] new entry  in song idx :{mysong['song_idx']} and verse={idx+1}")    
    mySongs_sql.create_entry(**mysong)
del mysong['sloka_eng']

list_sloka = song['sloka_hindi'].split('\n\n')
for idx, sloka in enumerate(list_sloka):
    # print(idx)
    mysong['slokas_no']   = idx+1
    mysong['sloka_hindi']   = sloka.strip()
    print(f"[sloka_hindi] new entry  in song idx :{mysong['song_idx']} and verse={idx+1}")    
    mySongs_sql.update_entry( *['song_idx','slokas_no']  , **mysong)
del mysong['sloka_hindi']

list_sloka = song['translation'].split('\n\n')    
for idx, sloka in enumerate(list_sloka):
    # print(idx)
    mysong['slokas_no']   = idx+1
    mysong['translation']   = sloka.strip()
    print(f"[translation] new entry  in song idx :{mysong['song_idx']} and verse={idx+1}")        
    mySongs_sql.update_entry( *['song_idx','slokas_no']  , **mysong)
del mysong['translation']
# Out:
# [sloka_eng] new entry  in song idx :77 and verse=1
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=2
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=3
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=4
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=5
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=6
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=7
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=8
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=9
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=10
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=11
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_eng] new entry  in song idx :77 and verse=12
# Can't Create new Entry! Already Existing Entry! UNIQUE constraint failed: Songs.song_idx, Songs.slokas_no
# [sloka_hindi] new entry  in song idx :77 and verse=1
# [sloka_hindi] new entry  in song idx :77 and verse=2
# [sloka_hindi] new entry  in song idx :77 and verse=3
# [sloka_hindi] new entry  in song idx :77 and verse=4
# [sloka_hindi] new entry  in song idx :77 and verse=5
# [sloka_hindi] new entry  in song idx :77 and verse=6
# [sloka_hindi] new entry  in song idx :77 and verse=7
# [sloka_hindi] new entry  in song idx :77 and verse=8
# [sloka_hindi] new entry  in song idx :77 and verse=9
# [sloka_hindi] new entry  in song idx :77 and verse=10
# [sloka_hindi] new entry  in song idx :77 and verse=11
# [sloka_hindi] new entry  in song idx :77 and verse=12
# [translation] new entry  in song idx :77 and verse=1
# [translation] new entry  in song idx :77 and verse=2
# [translation] new entry  in song idx :77 and verse=3
# [translation] new entry  in song idx :77 and verse=4
# [translation] new entry  in song idx :77 and verse=5
# [translation] new entry  in song idx :77 and verse=6
# [translation] new entry  in song idx :77 and verse=7
# [translation] new entry  in song idx :77 and verse=8
# [translation] new entry  in song idx :77 and verse=9
# [translation] new entry  in song idx :77 and verse=10
# [translation] new entry  in song idx :77 and verse=11
# [translation] new entry  in song idx :77 and verse=12

# %% [markdown]
# ##### 3nd Step: `TODO` Create new word(key,meaning) in dictionary.db

# %%
x =requests.request('GET', url.replace('stotras','dictionary/stotras').replace('php','txt') )
line_list = x.text.split('\r\n')
for dict_entry in get_dic_list(line_list):
    dicword, dicmeaning = get_query_dic(dict_entry,url)    
    create_dict_entry(DictonaryMeaning_sql, DictonaryWord_sql, dicword, dicmeaning)
    print('# mainword:',dicword, dicmeaning ) 
    if 'subwords' in dict_entry.keys() :     
        for dict_subword in dict_entry['subwords']:
            dicword, dicmeaning = get_query_dic(dict_subword,url)    
            create_dict_entry(DictonaryMeaning_sql, DictonaryWord_sql, dicword, dicmeaning)
            print('\t# subword:',dicword, dicmeaning)
            # print(dicword, dicmeaning )
# Out:
# # # get_dic_list: item before subword list maunav-yaakh-yaa__<span class='mword'>&#x092E;&#x094C;&#x0928;&#x0935;&#x094D;&#x092F;&#x093E;&#x0916;&#x094D;&#x092F;&#x093E;</span> (<span class='trans1'>Mauna-Vyaakhyaa</span>): Exposition through Profound Silence <br/> <span class='mng'>&#x092E;&#x094C;&#x0928;</span> (<span class='trans2'>Mauna</span>) = Silence <br/> <span class='mng'>&#x0935;&#x094D;&#x092F;&#x093E;&#x0916;&#x094D;&#x092F;&#x093E;</span> (<span class='trans2'>Vyaakhyaa</span>) = Explanation, Exposition
# ['maunav-yaakh-yaa', 'मौनव्याख्या (Mauna-Vyaakhyaa): Exposition through Profound Silence ']
# # sub_word_list:  [" <span class='mng'>&#x092E;&#x094C;&#x0928;</span> (<span class='trans2'>Mauna</span>) = Silence ", " <span class='mng'>&#x0935;&#x094D;&#x092F;&#x093E;&#x0916;&#x094D;&#x092F;&#x093E;</span> (<span class='trans2'>Vyaakhyaa</span>) = Explanation, Exposition"]
# # Subword:   मौन (Mauna) = Silence
# # Subword:   व्याख्या (Vyaakhyaa) = Explanation, Exposition
# ['p-rakattita', 'प्रकटित (Prakattita): Manifested, Unfolded, Proclaimed']
# # # get_dic_list: item before subword list parab-rah-matat-t-vam__<span class='mword'>&#x092A;&#x0930;&#x092C;&#x094D;&#x0930;&#x0939;&#x094D;&#x092E;&#x0924;&#x0924;&#x094D;&#x0924;&#x094D;&#x0935;&#x0902;</span> (<span class='trans1'>Parabrahmatattvam</span>): The Knowledge of the Supreme Brahman <br/> <span class='mng'>&#x092A;&#x0930;</span> (<span class='trans2'>Para</span>) = Supreme <br/> <span class='mng'>&#x092C;&#x094D;&#x0930;&#x0939;&#x094D;&#x092E;</span> (<span class='trans2'>Brahma</span>) = Brahma, the Absolute Consciousness <br/> <span class='mng'>&#x0924;&#x0924;&#x094D;&#x0924;&#x094D;&#x0935;</span> (<span class='trans2'>Tattva</span>) = True Principle
# ['parab-rah-matat-t-vam', 'परब्रह्मतत्त्वं (Parabrahmatattvam): The Knowledge of the Supreme Brahman ']
# # sub_word_list:  [" <span class='mng'>&#x092A;&#x0930;</span> (<span class='trans2'>Para</span>) = Supreme ", " <span class='mng'>&#x092C;&#x094D;&#x0930;&#x0939;&#x094D;&#x092E;</span> (<span class='trans2'>Brahma</span>) = Brahma, the Absolute Consciousness ", " <span class='mng'>&#x0924;&#x0924;&#x094D;&#x0924;&#x094D;&#x0935;</span> (<span class='trans2'>Tattva</span>) = True Principle"]
# # Subword:   पर (Para) = Supreme
# # Subword:   ब्रह्म (Brahma) = Brahma, the Absolute Consciousness
# # Subword:   तत्त्व (Tattva) = True Principle
# # # get_dic_list: item before subword list yuvaanam__<span class='mword'>&#x092F;&#x0941;&#x0935;&#x093E;&#x0928;&#x0902;</span> (<span class='trans1'>Yuvaanam</span>): Youthful <br/> <span class='mng'>&#x092F;&#x0941;&#x0935;&#x0928;&#x094D;</span> (<span class='trans2'>Yuvan</span>) = Youth, Young
# ['yuvaanam', 'युवानं (Yuvaanam): Youthful ']
# # sub_word_list:  [" <span class='mng'>&#x092F;&#x0941;&#x0935;&#x0928;&#x094D;</span> (<span class='trans2'>Yuvan</span>) = Youth, Young"]
# # Subword:   युवन् (Yuvan) = Youth, Young
# # # get_dic_list: item before subword list var-ssiss-tthaamte__<span class='mword'>&#x0935;&#x0930;&#x094D;&#x0937;&#x093F;&#x0937;&#x094D;&#x0920;&#x093E;&#x0902;&#x0924;&#x0947;</span> (<span class='trans1'>Varssisstthaamte</span>): Who is Sitting among Old and Great <span class='desc'>[Sages]</span> <br/> <span class='mng'>&#x0935;&#x0930;&#x094D;&#x0937;&#x093F;&#x0937;&#x094D;&#x0920;</span> (<span class='trans2'>Varssissttha</span>) = Very Great, Very Old <br/> <span class='mng'>&#x0924;&#x0947;</span> (<span class='trans2'>Te</span>) = He
# ['var-ssiss-tthaamte', 'वर्षिष्ठांते (Varssisstthaamte): Who is Sitting among Old and Great [Sages] ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x0930;&#x094D;&#x0937;&#x093F;&#x0937;&#x094D;&#x0920;</span> (<span class='trans2'>Varssissttha</span>) = Very Great, Very Old ", " <span class='mng'>&#x0924;&#x0947;</span> (<span class='trans2'>Te</span>) = He"]
# # Subword:   वर्षिष्ठ (Varssissttha) = Very Great, Very Old
# # Subword:   ते (Te) = He
# # # get_dic_list: item before subword list vasad-__<span class='mword'>&#x0935;&#x0938;&#x0926;&#x094D;</span> (<span class='trans1'>Vasad</span>): Sitting <br/> <span class='mng'>&#x0935;&#x0938;</span> (<span class='trans2'>Vasa</span>) = Dwelling, Residing
# ['vasad-', 'वसद् (Vasad): Sitting ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x0938;</span> (<span class='trans2'>Vasa</span>) = Dwelling, Residing"]
# # Subword:   वस (Vasa) = Dwelling, Residing
# # # get_dic_list: item before subword list r2ssigannaih2__<span class='mword'>&#x090B;&#x0937;&#x093F;&#x0917;&#x0923;&#x0948;&#x0903;</span> (<span class='trans1'>Rssigannaih</span>): By Group of Sages <br/> <span class='mng'>&#x090B;&#x0937;&#x093F;</span> (<span class='trans2'>Rssi</span>) = Sage <br/> <span class='mng'>&#x0917;&#x0923;</span> (<span class='trans2'>Ganna</span>) = Group, Multitude
# ['r2ssigannaih2', 'ऋषिगणैः (Rssigannaih): By Group of Sages ']
# # sub_word_list:  [" <span class='mng'>&#x090B;&#x0937;&#x093F;</span> (<span class='trans2'>Rssi</span>) = Sage ", " <span class='mng'>&#x0917;&#x0923;</span> (<span class='trans2'>Ganna</span>) = Group, Multitude"]
# # Subword:   ऋषि (Rssi) = Sage
# # Subword:   गण (Ganna) = Group, Multitude
# ['aa2vrtam', 'आवृतं (Aavrtam): Surrounded']
# # # get_dic_list: item before subword list b-rah-maniss-tthaih2__<span class='mword'>&#x092C;&#x094D;&#x0930;&#x0939;&#x094D;&#x092E;&#x0928;&#x093F;&#x0937;&#x094D;&#x0920;&#x0948;&#x0903;</span> (<span class='trans1'>Brahmanisstthaih</span>): Devoted to Brahman <br/> <span class='mng'>&#x092C;&#x094D;&#x0930;&#x0939;&#x094D;&#x092E;</span> (<span class='trans2'>Brahma</span>) = Brahma, the Absolute Consciousness <br/> <span class='mng'>&#x0928;&#x093F;&#x0937;&#x094D;&#x0920;</span> (<span class='trans2'>Nissttha</span>) = Devoted to
# ['b-rah-maniss-tthaih2', 'ब्रह्मनिष्ठैः (Brahmanisstthaih): Devoted to Brahman ']
# # sub_word_list:  [" <span class='mng'>&#x092C;&#x094D;&#x0930;&#x0939;&#x094D;&#x092E;</span> (<span class='trans2'>Brahma</span>) = Brahma, the Absolute Consciousness ", " <span class='mng'>&#x0928;&#x093F;&#x0937;&#x094D;&#x0920;</span> (<span class='trans2'>Nissttha</span>) = Devoted to"]
# # Subword:   ब्रह्म (Brahma) = Brahma, the Absolute Consciousness
# # Subword:   निष्ठ (Nissttha) = Devoted to
# # # get_dic_list: item before subword list aa2caar-yen-d-ram__<span class='mword'>&#x0906;&#x091A;&#x093E;&#x0930;&#x094D;&#x092F;&#x0947;&#x0928;&#x094D;&#x0926;&#x094D;&#x0930;&#x0902;</span> (<span class='trans1'>Aacaaryendram</span>): Supreme Teacher <br/> <span class='mng'>&#x0906;&#x091A;&#x093E;&#x0930;&#x094D;&#x092F;</span> (<span class='trans2'>Aacaarya</span>) = Spiritual Teacher <br/> <span class='mng'>&#x0907;&#x0928;&#x094D;&#x0926;&#x094D;&#x0930;</span> (<span class='trans2'>Indra</span>) = Best, Excellent
# ['aa2caar-yen-d-ram', 'आचार्येन्द्रं (Aacaaryendram): Supreme Teacher ']
# # sub_word_list:  [" <span class='mng'>&#x0906;&#x091A;&#x093E;&#x0930;&#x094D;&#x092F;</span> (<span class='trans2'>Aacaarya</span>) = Spiritual Teacher ", " <span class='mng'>&#x0907;&#x0928;&#x094D;&#x0926;&#x094D;&#x0930;</span> (<span class='trans2'>Indra</span>) = Best, Excellent"]
# # Subword:   आचार्य (Aacaarya) = Spiritual Teacher
# # Subword:   इन्द्र (Indra) = Best, Excellent
# # # get_dic_list: item before subword list karakalita__<span class='mword'>&#x0915;&#x0930;&#x0915;&#x0932;&#x093F;&#x0924;</span> (<span class='trans1'>Karakalita</span>): Hands Forming <span class='desc'>[the Cin-Mudra]</span> <br/> <span class='mng'>&#x0915;&#x0930;</span> (<span class='trans2'>Kara</span>) = Hand <br/> <span class='mng'>&#x0915;&#x0932;&#x093F;&#x0924;</span> (<span class='trans2'>Kalita</span>) = Made, Formed
# ['karakalita', 'करकलित (Karakalita): Hands Forming [the Cin-Mudra] ']
# # sub_word_list:  [" <span class='mng'>&#x0915;&#x0930;</span> (<span class='trans2'>Kara</span>) = Hand ", " <span class='mng'>&#x0915;&#x0932;&#x093F;&#x0924;</span> (<span class='trans2'>Kalita</span>) = Made, Formed"]
# # Subword:   कर (Kara) = Hand
# # Subword:   कलित (Kalita) = Made, Formed
# # # get_dic_list: item before subword list cin-mud-ramaanamdamuur-tim__<span class='mword'>&#x091A;&#x093F;&#x0928;&#x094D;&#x092E;&#x0941;&#x0926;&#x094D;&#x0930;&#x092E;&#x093E;&#x0928;&#x0902;&#x0926;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;&#x0902;</span> (<span class='trans1'>Cinmudramaanamdamuurtim</span>): <span class='desc'>[Hand Forming the]</span> Cin-Mudra and Figure <span class='desc'>[is Still]</span> <br/> <span class='mng'>&#x091A;&#x093F;&#x0924;&#x094D;</span> (<span class='trans2'>Cit</span>) = Consciousness <br/> <span class='mng'>&#x092E;&#x0941;&#x0926;&#x094D;&#x0930;&#x093E;</span> (<span class='trans2'>Mudraa</span>) = Hand Gesture <br/> <span class='mng'>&#x0906;&#x0928;&#x0928;&#x094D;&#x0926;</span> (<span class='trans2'>Aananda</span>) = Blissful <br/> <span class='mng'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Muurti</span>) = Form, Figure
# ['cin-mud-ramaanamdamuur-tim', 'चिन्मुद्रमानंदमूर्तिं (Cinmudramaanamdamuurtim): [Hand Forming the] Cin-Mudra and Figure [is Still] ']
# # sub_word_list:  [" <span class='mng'>&#x091A;&#x093F;&#x0924;&#x094D;</span> (<span class='trans2'>Cit</span>) = Consciousness ", " <span class='mng'>&#x092E;&#x0941;&#x0926;&#x094D;&#x0930;&#x093E;</span> (<span class='trans2'>Mudraa</span>) = Hand Gesture ", " <span class='mng'>&#x0906;&#x0928;&#x0928;&#x094D;&#x0926;</span> (<span class='trans2'>Aananda</span>) = Blissful ", " <span class='mng'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Muurti</span>) = Form, Figure"]
# # Subword:   चित् (Cit) = Consciousness
# # Subword:   मुद्रा (Mudraa) = Hand Gesture
# # Subword:   आनन्द (Aananda) = Blissful
# # Subword:   मूर्ति (Muurti) = Form, Figure
# # # get_dic_list: item before subword list s-vaat-maaraamam__<span class='mword'>&#x0938;&#x094D;&#x0935;&#x093E;&#x0924;&#x094D;&#x092E;&#x093E;&#x0930;&#x093E;&#x092E;&#x0902;</span> (<span class='trans1'>Svaatmaaraamam</span>): Rejoicing in His Own Self <br/> <span class='mng'>&#x0938;&#x094D;&#x0935;</span> (<span class='trans2'>Sva</span>) = One's Own <br/> <span class='mng'>&#x0906;&#x0924;&#x094D;&#x092E;&#x093E;&#x0930;&#x093E;&#x092E;</span> (<span class='trans2'>Aatmaaraama</span>) = Rejoicing in One's Self
# ['s-vaat-maaraamam', 'स्वात्मारामं (Svaatmaaraamam): Rejoicing in His Own Self ']
# # sub_word_list:  [" <span class='mng'>&#x0938;&#x094D;&#x0935;</span> (<span class='trans2'>Sva</span>) = One's Own ", " <span class='mng'>&#x0906;&#x0924;&#x094D;&#x092E;&#x093E;&#x0930;&#x093E;&#x092E;</span> (<span class='trans2'>Aatmaaraama</span>) = Rejoicing in One's Self"]
# # Subword:   स्व (Sva) = One's Own
# # Subword:   आत्माराम (Aatmaaraama) = Rejoicing in One's Self
# # # get_dic_list: item before subword list muditavadanam__<span class='mword'>&#x092E;&#x0941;&#x0926;&#x093F;&#x0924;&#x0935;&#x0926;&#x0928;&#x0902;</span> (<span class='trans1'>Muditavadanam</span>): Blissful Face <br/> <span class='mng'>&#x092E;&#x0941;&#x0926;&#x093F;&#x0924;</span> (<span class='trans2'>Mudita</span>) = Delighted, Joyful <br/> <span class='mng'>&#x0935;&#x0926;&#x0928;</span> (<span class='trans2'>Vadana</span>) = Face
# ['muditavadanam', 'मुदितवदनं (Muditavadanam): Blissful Face ']
# # sub_word_list:  [" <span class='mng'>&#x092E;&#x0941;&#x0926;&#x093F;&#x0924;</span> (<span class='trans2'>Mudita</span>) = Delighted, Joyful ", " <span class='mng'>&#x0935;&#x0926;&#x0928;</span> (<span class='trans2'>Vadana</span>) = Face"]
# # Subword:   मुदित (Mudita) = Delighted, Joyful
# # Subword:   वदन (Vadana) = Face
# # # get_dic_list: item before subword list dak-ssinnaamuur-timiidde__<span class='mword'>&#x0926;&#x0915;&#x094D;&#x0937;&#x093F;&#x0923;&#x093E;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;&#x092E;&#x0940;&#x0921;&#x0947;</span> (<span class='trans1'>Dakssinnaamuurtimiidde</span>): Salutations to Sri Dakshinamurthy <br/> <span class='mng'>&#x0926;&#x0915;&#x094D;&#x0937;&#x093F;&#x0923;&#x093E;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Dakssinnaamuurti</span>) = Sri Dakshinamurthy <br/> <span class='mng'>&#x0908;&#x0921;&#x094D;</span> (<span class='trans2'>Iidd</span>) = Praise, Extolling
# ['dak-ssinnaamuur-timiidde', 'दक्षिणामूर्तिमीडे (Dakssinnaamuurtimiidde): Salutations to Sri Dakshinamurthy ']
# # sub_word_list:  [" <span class='mng'>&#x0926;&#x0915;&#x094D;&#x0937;&#x093F;&#x0923;&#x093E;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Dakssinnaamuurti</span>) = Sri Dakshinamurthy ", " <span class='mng'>&#x0908;&#x0921;&#x094D;</span> (<span class='trans2'>Iidd</span>) = Praise, Extolling"]
# # Subword:   दक्षिणामूर्ति (Dakssinnaamuurti) = Sri Dakshinamurthy
# # Subword:   ईड् (Iidd) = Praise, Extolling
# # # get_dic_list: item before subword list vattavittapisamiipebhuumibhaage__<span class='mword'>&#x0935;&#x091F;&#x0935;&#x093F;&#x091F;&#x092A;&#x093F;&#x0938;&#x092E;&#x0940;&#x092A;&#x0947;&#x092D;&#x0942;&#x092E;&#x093F;&#x092D;&#x093E;&#x0917;&#x0947;</span> (<span class='trans1'>Vatta-Vittapi-Samiipe-Bhuumi-Bhaage</span>): <span class='desc'>[Sitting on the]</span> ground near the Banyan Tree]</span> <br/> <span class='mng'>&#x0935;&#x091F;</span> (<span class='trans2'>Vatta</span>) = Banyan Tree <br/> <span class='mng'>&#x0935;&#x093F;&#x091F;&#x092A;&#x093F;&#x0928;&#x094D;</span> (<span class='trans2'>Vittapin</span>) = Having branches or boughs, a Tree, Fig Tree <br/> <span class='mng'>&#x0938;&#x092E;&#x0940;&#x092A;</span> (<span class='trans2'>Samiipa</span>) = Near, Adjacent, Close by <br/> <span class='mng'>&#x092D;&#x0942;&#x092E;&#x093F;</span> (<span class='trans2'>Bhuumi</span>) = Ground, Place, Earth <br/> <span class='mng'>&#x092D;&#x093E;&#x0917;</span> (<span class='trans2'>Bhaaga</span>) = Part, Portion
# ['vattavittapisamiipebhuumibhaage', 'वटविटपिसमीपेभूमिभागे (Vatta-Vittapi-Samiipe-Bhuumi-Bhaage): [Sitting on the] ground near the Banyan Tree] ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x091F;</span> (<span class='trans2'>Vatta</span>) = Banyan Tree ", " <span class='mng'>&#x0935;&#x093F;&#x091F;&#x092A;&#x093F;&#x0928;&#x094D;</span> (<span class='trans2'>Vittapin</span>) = Having branches or boughs, a Tree, Fig Tree ", " <span class='mng'>&#x0938;&#x092E;&#x0940;&#x092A;</span> (<span class='trans2'>Samiipa</span>) = Near, Adjacent, Close by ", " <span class='mng'>&#x092D;&#x0942;&#x092E;&#x093F;</span> (<span class='trans2'>Bhuumi</span>) = Ground, Place, Earth ", " <span class='mng'>&#x092D;&#x093E;&#x0917;</span> (<span class='trans2'>Bhaaga</span>) = Part, Portion"]
# # Subword:   वट (Vatta) = Banyan Tree
# # Subword:   विटपिन् (Vittapin) = Having branches or boughs, a Tree, Fig Tree
# # Subword:   समीप (Samiipa) = Near, Adjacent, Close by
# # Subword:   भूमि (Bhuumi) = Ground, Place, Earth
# # Subword:   भाग (Bhaaga) = Part, Portion
# ['nissann-nnam', 'निषण्णं (Nissannnnam): Sitting, Seat']
# # # get_dic_list: item before subword list sakalamunijanaanaam__<span class='mword'>&#x0938;&#x0915;&#x0932;&#x092E;&#x0941;&#x0928;&#x093F;&#x091C;&#x0928;&#x093E;&#x0928;&#x093E;&#x0902;</span> (<span class='trans1'>Sakala-Muni-Janaanaam</span>): All Munis <span class='desc'>[Sages]</span> <br/> <span class='mng'>&#x0938;&#x0915;&#x0932;</span> (<span class='trans2'>Sakala</span>) = All <br/> <span class='mng'>&#x092E;&#x0941;&#x0928;&#x093F;</span> (<span class='trans2'>Muni</span>) = Muni, Sage <br/> <span class='mng'>&#x091C;&#x0928;</span> (<span class='trans2'>Jana</span>) = Person collectively
# ['sakalamunijanaanaam', 'सकलमुनिजनानां (Sakala-Muni-Janaanaam): All Munis [Sages] ']
# # sub_word_list:  [" <span class='mng'>&#x0938;&#x0915;&#x0932;</span> (<span class='trans2'>Sakala</span>) = All ", " <span class='mng'>&#x092E;&#x0941;&#x0928;&#x093F;</span> (<span class='trans2'>Muni</span>) = Muni, Sage ", " <span class='mng'>&#x091C;&#x0928;</span> (<span class='trans2'>Jana</span>) = Person collectively"]
# # Subword:   सकल (Sakala) = All
# # Subword:   मुनि (Muni) = Muni, Sage
# # Subword:   जन (Jana) = Person collectively
# # # get_dic_list: item before subword list j-nyaanadaataaramaaraat-__<span class='mword'>&#x091C;&#x094D;&#x091E;&#x093E;&#x0928;&#x0926;&#x093E;&#x0924;&#x093E;&#x0930;&#x092E;&#x093E;&#x0930;&#x093E;&#x0924;&#x094D;</span> (<span class='trans1'>Jnyaana-Daataaram-Aaraat</span>): <span class='desc'>[All Munis were sitting]</span> near to the bestower of Knowledge <br/> <span class='mng'>&#x091C;&#x094D;&#x091E;&#x093E;&#x0928;</span> (<span class='trans2'>Jnyaana</span>) = Knowledge <br/> <span class='mng'>&#x0926;&#x093E;&#x0924;&#x093E;</span> (<span class='trans2'>Daataa</span>) = Giver <br/> <span class='mng'>&#x0906;&#x0930;&#x093E;&#x0924;&#x094D;</span> (<span class='trans2'>Aaraat</span>) = Near, Directly, Immediately
# ['j-nyaanadaataaramaaraat-', 'ज्ञानदातारमारात् (Jnyaana-Daataaram-Aaraat): [All Munis were sitting] near to the bestower of Knowledge ']
# # sub_word_list:  [" <span class='mng'>&#x091C;&#x094D;&#x091E;&#x093E;&#x0928;</span> (<span class='trans2'>Jnyaana</span>) = Knowledge ", " <span class='mng'>&#x0926;&#x093E;&#x0924;&#x093E;</span> (<span class='trans2'>Daataa</span>) = Giver ", " <span class='mng'>&#x0906;&#x0930;&#x093E;&#x0924;&#x094D;</span> (<span class='trans2'>Aaraat</span>) = Near, Directly, Immediately"]
# # Subword:   ज्ञान (Jnyaana) = Knowledge
# # Subword:   दाता (Daataa) = Giver
# # Subword:   आरात् (Aaraat) = Near, Directly, Immediately
# # # get_dic_list: item before subword list t-ribhuvanagurumiisham__<span class='mword'>&#x0924;&#x094D;&#x0930;&#x093F;&#x092D;&#x0941;&#x0935;&#x0928;&#x0917;&#x0941;&#x0930;&#x0941;&#x092E;&#x0940;&#x0936;&#x0902;</span> (<span class='trans1'>Tri-Bhuvana-Gurum-Iisham</span>): Guru of the Three Worlds, the Lord Himself <br/> <span class='mng'>&#x0924;&#x094D;&#x0930;&#x093F;</span> (<span class='trans2'>Tri</span>) = Three <br/> <span class='mng'>&#x092D;&#x0941;&#x0935;&#x0928;</span> (<span class='trans2'>Bhuvana</span>) = World <br/> <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru <br/> <span class='mng'>&#x0908;&#x0936;</span> (<span class='trans2'>Iisha</span>) = Lord
# ['t-ribhuvanagurumiisham', 'त्रिभुवनगुरुमीशं (Tri-Bhuvana-Gurum-Iisham): Guru of the Three Worlds, the Lord Himself ']
# # sub_word_list:  [" <span class='mng'>&#x0924;&#x094D;&#x0930;&#x093F;</span> (<span class='trans2'>Tri</span>) = Three ", " <span class='mng'>&#x092D;&#x0941;&#x0935;&#x0928;</span> (<span class='trans2'>Bhuvana</span>) = World ", " <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru ", " <span class='mng'>&#x0908;&#x0936;</span> (<span class='trans2'>Iisha</span>) = Lord"]
# # Subword:   त्रि (Tri) = Three
# # Subword:   भुवन (Bhuvana) = World
# # Subword:   गुरु (Guru) = Guru
# # Subword:   ईश (Iisha) = Lord
# # # get_dic_list: item before subword list dak-ssinnaamuur-tidevam__<span class='mword'>&#x0926;&#x0915;&#x094D;&#x0937;&#x093F;&#x0923;&#x093E;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;&#x0926;&#x0947;&#x0935;&#x0902;</span> (<span class='trans1'>Dakssinnaamuurti-Devam</span>): Dakshinamurthy Deva <br/> <span class='mng'>&#x0926;&#x0915;&#x094D;&#x0937;&#x093F;&#x0923;&#x093E;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Dakssinnaamuurti</span>) = Dakshinamurthy <br/> <span class='mng'>&#x0926;&#x0947;&#x0935;</span> (<span class='trans2'>Deva</span>) = Deva, Lord
# ['dak-ssinnaamuur-tidevam', 'दक्षिणामूर्तिदेवं (Dakssinnaamuurti-Devam): Dakshinamurthy Deva ']
# # sub_word_list:  [" <span class='mng'>&#x0926;&#x0915;&#x094D;&#x0937;&#x093F;&#x0923;&#x093E;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Dakssinnaamuurti</span>) = Dakshinamurthy ", " <span class='mng'>&#x0926;&#x0947;&#x0935;</span> (<span class='trans2'>Deva</span>) = Deva, Lord"]
# # Subword:   दक्षिणामूर्ति (Dakssinnaamuurti) = Dakshinamurthy
# # Subword:   देव (Deva) = Deva, Lord
# # # get_dic_list: item before subword list jananamarannaduh2khac-cheda__<span class='mword'>&#x091C;&#x0928;&#x0928;&#x092E;&#x0930;&#x0923;&#x0926;&#x0941;&#x0903;&#x0916;&#x091A;&#x094D;&#x091B;&#x0947;&#x0926;</span> (<span class='trans1'>Janana-Maranna-Duhkhac-Cheda</span>): <span class='desc'>[Expert]</span> in severing the sorrows resulting from the cycles of Births and Deaths <br/> <span class='mng'>&#x091C;&#x0928;&#x0928;</span> (<span class='trans2'>Janana</span>) = Generating, Begetting, Producing, Birth <br/> <span class='mng'>&#x092E;&#x0930;&#x0923;</span> (<span class='trans2'>Maranna</span>) = Death <br/> <span class='mng'>&#x0926;&#x0941;&#x0903;&#x0916;</span> (<span class='trans2'>Duhkha</span>) = Sorrow <br/> <span class='mng'>&#x091B;&#x0947;&#x0926;</span> (<span class='trans2'>Cheda</span>) = Cutting off
# ['jananamarannaduh2khac-cheda', 'जननमरणदुःखच्छेद (Janana-Maranna-Duhkhac-Cheda): [Expert] in severing the sorrows resulting from the cycles of Births and Deaths ']
# # sub_word_list:  [" <span class='mng'>&#x091C;&#x0928;&#x0928;</span> (<span class='trans2'>Janana</span>) = Generating, Begetting, Producing, Birth ", " <span class='mng'>&#x092E;&#x0930;&#x0923;</span> (<span class='trans2'>Maranna</span>) = Death ", " <span class='mng'>&#x0926;&#x0941;&#x0903;&#x0916;</span> (<span class='trans2'>Duhkha</span>) = Sorrow ", " <span class='mng'>&#x091B;&#x0947;&#x0926;</span> (<span class='trans2'>Cheda</span>) = Cutting off"]
# # Subword:   जनन (Janana) = Generating, Begetting, Producing, Birth
# # Subword:   मरण (Maranna) = Death
# # Subword:   दुःख (Duhkha) = Sorrow
# # Subword:   छेद (Cheda) = Cutting off
# ['dak-ssam', 'दक्षं (Dakssam): Adroit, Expert']
# # # get_dic_list: item before subword list namaami__<span class='mword'>&#x0928;&#x092E;&#x093E;&#x092E;&#x093F;</span> (<span class='trans1'>Namaami</span>): I bow <br/> <span class='mng'>&#x0928;&#x092E;&#x0938;&#x094D;</span> (<span class='trans2'>Namas</span>) = Reverential Salutation, Bow, Obeisance
# ['namaami', 'नमामि (Namaami): I bow ']
# # sub_word_list:  [" <span class='mng'>&#x0928;&#x092E;&#x0938;&#x094D;</span> (<span class='trans2'>Namas</span>) = Reverential Salutation, Bow, Obeisance"]
# # Subword:   नमस् (Namas) = Reverential Salutation, Bow, Obeisance
# ['cit-ram', 'चित्रं (Citram): Strange, Wonderful, also Picture, Sketch']
# # # get_dic_list: item before subword list vattataror-muule__<span class='mword'>&#x0935;&#x091F;&#x0924;&#x0930;&#x094B;&#x0930;&#x094D;&#x092E;&#x0942;&#x0932;&#x0947;</span> (<span class='trans1'>Vatta-Taror-Muule</span>): Root <span class='desc'>[i.e. Base]</span> of the Banyan Tree <br/> <span class='mng'>&#x0935;&#x091F;</span> (<span class='trans2'>Vatta</span>) = Banyan <br/> <span class='mng'>&#x0924;&#x0930;&#x0941;</span> (<span class='trans2'>Taru</span>) = Tree <br/> <span class='mng'>&#x092E;&#x0942;&#x0932;</span> (<span class='trans2'>Muula</span>) = Root
# ['vattataror-muule', 'वटतरोर्मूले (Vatta-Taror-Muule): Root [i.e. Base] of the Banyan Tree ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x091F;</span> (<span class='trans2'>Vatta</span>) = Banyan ", " <span class='mng'>&#x0924;&#x0930;&#x0941;</span> (<span class='trans2'>Taru</span>) = Tree ", " <span class='mng'>&#x092E;&#x0942;&#x0932;</span> (<span class='trans2'>Muula</span>) = Root"]
# # Subword:   वट (Vatta) = Banyan
# # Subword:   तरु (Taru) = Tree
# # Subword:   मूल (Muula) = Root
# # # get_dic_list: item before subword list vrd-dhaah2__<span class='mword'>&#x0935;&#x0943;&#x0926;&#x094D;&#x0927;&#x093E;&#x0903;</span> (<span class='trans1'>Vrddhaah</span>): Aged <span class='desc'>[Disciples]</span> <br/> <span class='mng'>&#x0935;&#x0943;&#x0926;&#x094D;&#x0927;</span> (<span class='trans2'>Vrddha</span>) = Aged, Old
# ['vrd-dhaah2', 'वृद्धाः (Vrddhaah): Aged [Disciples] ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x0943;&#x0926;&#x094D;&#x0927;</span> (<span class='trans2'>Vrddha</span>) = Aged, Old"]
# # Subword:   वृद्ध (Vrddha) = Aged, Old
# ['shiss-yaa', 'शिष्या (Shissyaa): Disciples']
# # # get_dic_list: item before subword list gurur-yuvaa__<span class='mword'>&#x0917;&#x0941;&#x0930;&#x0941;&#x0930;&#x094D;&#x092F;&#x0941;&#x0935;&#x093E;</span> (<span class='trans1'>Gurur-Yuvaa</span>): Young Guru <br/> <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru <br/> <span class='mng'>&#x092F;&#x0941;&#x0935;&#x0928;&#x094D;</span> (<span class='trans2'>Yuvan</span>) = Young, Youth
# ['gurur-yuvaa', 'गुरुर्युवा (Gurur-Yuvaa): Young Guru ']
# # sub_word_list:  [" <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru ", " <span class='mng'>&#x092F;&#x0941;&#x0935;&#x0928;&#x094D;</span> (<span class='trans2'>Yuvan</span>) = Young, Youth"]
# # Subword:   गुरु (Guru) = Guru
# # Subword:   युवन् (Yuvan) = Young, Youth
# # # get_dic_list: item before subword list guros-tu__<span class='mword'>&#x0917;&#x0941;&#x0930;&#x094B;&#x0938;&#x094D;&#x0924;&#x0941;</span> (<span class='trans1'>Guros-Tu</span>): The Guru indeed <br/> <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru, Spiritual preceptor <br/> <span class='mng'>&#x0924;&#x0941;</span> (<span class='trans2'>Tu</span>) = But, sometimes for emphasis
# ['guros-tu', 'गुरोस्तु (Guros-Tu): The Guru indeed ']
# # sub_word_list:  [" <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru, Spiritual preceptor ", " <span class='mng'>&#x0924;&#x0941;</span> (<span class='trans2'>Tu</span>) = But, sometimes for emphasis"]
# # Subword:   गुरु (Guru) = Guru, Spiritual preceptor
# # Subword:   तु (Tu) = But, sometimes for emphasis
# ['maunam', 'मौनं (Maunam): Silence']
# ['v-yaakh-yaanam', 'व्याख्यानं (Vyaakhyaanam): Exposition, Explaining']
# # # get_dic_list: item before subword list shiss-yaas-tuc-chin-nasamshayaah2__<span class='mword'>&#x0936;&#x093F;&#x0937;&#x094D;&#x092F;&#x093E;&#x0938;&#x094D;&#x0924;&#x0941;&#x091A;&#x094D;&#x091B;&#x093F;&#x0928;&#x094D;&#x0928;&#x0938;&#x0902;&#x0936;&#x092F;&#x093E;&#x0903;</span> (<span class='trans1'>Shissyaas-Tuc-Chinna-Samshayaah</span>): <span class='desc'>[The Silence of the Guru]</span> is severing the doubts <span class='desc'>[automatically]</span> from the minds of the Disciples <br/> <span class='mng'>&#x0936;&#x093F;&#x0937;&#x094D;&#x092F;</span> (<span class='trans2'>Shissya</span>) = Disciple <br/> <span class='mng'>&#x0924;&#x0941;</span> (<span class='trans2'>Tu</span>) = But, sometimes for emphasis <br/> <span class='mng'>&#x091B;&#x093F;&#x0928;&#x094D;&#x0928;</span> (<span class='trans2'>Chinna</span>) = Cut off <br/> <span class='mng'>&#x0938;&#x0902;&#x0936;&#x092F;</span> (<span class='trans2'>Samshaya</span>) = Doubt
# ['shiss-yaas-tuc-chin-nasamshayaah2', 'शिष्यास्तुच्छिन्नसंशयाः (Shissyaas-Tuc-Chinna-Samshayaah): [The Silence of the Guru] is severing the doubts [automatically] from the minds of the Disciples ']
# # sub_word_list:  [" <span class='mng'>&#x0936;&#x093F;&#x0937;&#x094D;&#x092F;</span> (<span class='trans2'>Shissya</span>) = Disciple ", " <span class='mng'>&#x0924;&#x0941;</span> (<span class='trans2'>Tu</span>) = But, sometimes for emphasis ", " <span class='mng'>&#x091B;&#x093F;&#x0928;&#x094D;&#x0928;</span> (<span class='trans2'>Chinna</span>) = Cut off ", " <span class='mng'>&#x0938;&#x0902;&#x0936;&#x092F;</span> (<span class='trans2'>Samshaya</span>) = Doubt"]
# # Subword:   शिष्य (Shissya) = Disciple
# # Subword:   तु (Tu) = But, sometimes for emphasis
# # Subword:   छिन्न (Chinna) = Cut off
# # Subword:   संशय (Samshaya) = Doubt
# # # get_dic_list: item before subword list nidhaye__<span class='mword'>&#x0928;&#x093F;&#x0927;&#x092F;&#x0947;</span> (<span class='trans1'>Nidhaye</span>): Who is a receptacle <span class='desc'>[to all Knowledge]</span> <br/> <span class='mng'>&#x0928;&#x093F;&#x0927;&#x093F;</span> (<span class='trans2'>Nidhi</span>) = Storehouse
# ['nidhaye', 'निधये (Nidhaye): Who is a receptacle [to all Knowledge] ']
# # sub_word_list:  [" <span class='mng'>&#x0928;&#x093F;&#x0927;&#x093F;</span> (<span class='trans2'>Nidhi</span>) = Storehouse"]
# # Subword:   निधि (Nidhi) = Storehouse
# # # get_dic_list: item before subword list sar-vavid-yaanaam__<span class='mword'>&#x0938;&#x0930;&#x094D;&#x0935;&#x0935;&#x093F;&#x0926;&#x094D;&#x092F;&#x093E;&#x0928;&#x093E;&#x0902;</span> (<span class='trans1'>Sarva-Vidyaanaam</span>): All Knowledge <br/> <span class='mng'>&#x0938;&#x0930;&#x094D;&#x0935;</span> (<span class='trans2'>Sarva</span>) = All <br/> <span class='mng'>&#x0935;&#x093F;&#x0926;&#x094D;&#x092F;&#x093E;</span> (<span class='trans2'>Vidyaa</span>) = Knowledge
# ['sar-vavid-yaanaam', 'सर्वविद्यानां (Sarva-Vidyaanaam): All Knowledge ']
# # sub_word_list:  [" <span class='mng'>&#x0938;&#x0930;&#x094D;&#x0935;</span> (<span class='trans2'>Sarva</span>) = All ", " <span class='mng'>&#x0935;&#x093F;&#x0926;&#x094D;&#x092F;&#x093E;</span> (<span class='trans2'>Vidyaa</span>) = Knowledge"]
# # Subword:   सर्व (Sarva) = All
# # Subword:   विद्या (Vidyaa) = Knowledge
# # # get_dic_list: item before subword list bhissaje__<span class='mword'>&#x092D;&#x093F;&#x0937;&#x091C;&#x0947;</span> (<span class='trans1'>Bhissaje</span>): Who is a Medicine <span class='desc'>[to all the diseases of Worldly bondage]</span> <br/> <span class='mng'>&#x092D;&#x093F;&#x0937;&#x091C;&#x094D;</span> (<span class='trans2'>Bhissaj</span>) = Curing, Healing, Remedy, Medicine
# ['bhissaje', 'भिषजे (Bhissaje): Who is a Medicine [to all the diseases of Worldly bondage] ']
# # sub_word_list:  [" <span class='mng'>&#x092D;&#x093F;&#x0937;&#x091C;&#x094D;</span> (<span class='trans2'>Bhissaj</span>) = Curing, Healing, Remedy, Medicine"]
# # Subword:   भिषज् (Bhissaj) = Curing, Healing, Remedy, Medicine
# # # get_dic_list: item before subword list bhavaroginnaam-__<span class='mword'>&#x092D;&#x0935;&#x0930;&#x094B;&#x0917;&#x093F;&#x0923;&#x093E;&#x092E;&#x094D;</span> (<span class='trans1'>Bhava-Roginnaam</span>): Disease of Worldly bondage <br/> <span class='mng'>&#x092D;&#x0935;</span> (<span class='trans2'>Bhava</span>) = World <br/> <span class='mng'>&#x0930;&#x094B;&#x0917;&#x093F;&#x0928;&#x094D;</span> (<span class='trans2'>Rogin</span>) = Sick, Ill, Diseased
# ['bhavaroginnaam-', 'भवरोगिणाम् (Bhava-Roginnaam): Disease of Worldly bondage ']
# # sub_word_list:  [" <span class='mng'>&#x092D;&#x0935;</span> (<span class='trans2'>Bhava</span>) = World ", " <span class='mng'>&#x0930;&#x094B;&#x0917;&#x093F;&#x0928;&#x094D;</span> (<span class='trans2'>Rogin</span>) = Sick, Ill, Diseased"]
# # Subword:   भव (Bhava) = World
# # Subword:   रोगिन् (Rogin) = Sick, Ill, Diseased
# # # get_dic_list: item before subword list gurave__<span class='mword'>&#x0917;&#x0941;&#x0930;&#x0935;&#x0947;</span> (<span class='trans1'>Gurave</span>): Who is the Guru <span class='desc'>[to all the Worlds]</span> <br/> <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru, Spiritual Preceptor
# ['gurave', 'गुरवे (Gurave): Who is the Guru [to all the Worlds] ']
# # sub_word_list:  [" <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru, Spiritual Preceptor"]
# # Subword:   गुरु (Guru) = Guru, Spiritual Preceptor
# # # get_dic_list: item before subword list sar-valokaanaam__<span class='mword'>&#x0938;&#x0930;&#x094D;&#x0935;&#x0932;&#x094B;&#x0915;&#x093E;&#x0928;&#x093E;&#x0902;</span> (<span class='trans1'>Sarva-Lokaanaam</span>): All Worlds <br/> <span class='mng'>&#x0938;&#x0930;&#x094D;&#x0935;</span> (<span class='trans2'>Sarva</span>) = All <br/> <span class='mng'>&#x0932;&#x094B;&#x0915;</span> (<span class='trans2'>Loka</span>) = World
# ['sar-valokaanaam', 'सर्वलोकानां (Sarva-Lokaanaam): All Worlds ']
# # sub_word_list:  [" <span class='mng'>&#x0938;&#x0930;&#x094D;&#x0935;</span> (<span class='trans2'>Sarva</span>) = All ", " <span class='mng'>&#x0932;&#x094B;&#x0915;</span> (<span class='trans2'>Loka</span>) = World"]
# # Subword:   सर्व (Sarva) = All
# # Subword:   लोक (Loka) = World
# ['dak-ssinnaamuur-taye', 'दक्षिणामूर्तये (Dakssinnaamuurtaye): To Dakshinamurthy']
# ['namah2', 'नमः (Namah): Salutations']
# ['om', 'ॐ (Om): Om, symbol of Parabrahman']
# # # get_dic_list: item before subword list p-rannavaar-thaaya__<span class='mword'>&#x092A;&#x094D;&#x0930;&#x0923;&#x0935;&#x093E;&#x0930;&#x094D;&#x0925;&#x093E;&#x092F;</span> (<span class='trans1'>Prannava-Arthaaya</span>): To the Embodiment of Pranava <span class='desc'>[Om]</span> <br/> <span class='mng'>&#x092A;&#x094D;&#x0930;&#x0923;&#x0935;</span> (<span class='trans2'>Prannava</span>) = Pranava, Om <br/> <span class='mng'>&#x0905;&#x0930;&#x094D;&#x0925;</span> (<span class='trans2'>Artha</span>) = Meaning, Substance
# ['p-rannavaar-thaaya', 'प्रणवार्थाय (Prannava-Arthaaya): To the Embodiment of Pranava [Om] ']
# # sub_word_list:  [" <span class='mng'>&#x092A;&#x094D;&#x0930;&#x0923;&#x0935;</span> (<span class='trans2'>Prannava</span>) = Pranava, Om ", " <span class='mng'>&#x0905;&#x0930;&#x094D;&#x0925;</span> (<span class='trans2'>Artha</span>) = Meaning, Substance"]
# # Subword:   प्रणव (Prannava) = Pranava, Om
# # Subword:   अर्थ (Artha) = Meaning, Substance
# # # get_dic_list: item before subword list shud-dhaj-nyaanaikamuur-taye__<span class='mword'>&#x0936;&#x0941;&#x0926;&#x094D;&#x0927;&#x091C;&#x094D;&#x091E;&#x093E;&#x0928;&#x0948;&#x0915;&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x092F;&#x0947;</span> (<span class='trans1'>Shuddha-Jnyaana-Eka-Muurtaye</span>): To the Personification of Pure, Non-Dual Knowledge <br/> <span class='mng'>&#x0936;&#x0941;&#x0926;&#x094D;&#x0927;</span> (<span class='trans2'>Shuddha</span>) = Pure <br/> <span class='mng'>&#x091C;&#x094D;&#x091E;&#x093E;&#x0928;</span> (<span class='trans2'>Jnyaana</span>) = Knowledge <br/> <span class='mng'>&#x090F;&#x0915;</span> (<span class='trans2'>Eka</span>) = One <br/> <span class='mng'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Muurti</span>) = Form, Image, Embodiment, Personification
# ['shud-dhaj-nyaanaikamuur-taye', 'शुद्धज्ञानैकमूर्तये (Shuddha-Jnyaana-Eka-Muurtaye): To the Personification of Pure, Non-Dual Knowledge ']
# # sub_word_list:  [" <span class='mng'>&#x0936;&#x0941;&#x0926;&#x094D;&#x0927;</span> (<span class='trans2'>Shuddha</span>) = Pure ", " <span class='mng'>&#x091C;&#x094D;&#x091E;&#x093E;&#x0928;</span> (<span class='trans2'>Jnyaana</span>) = Knowledge ", " <span class='mng'>&#x090F;&#x0915;</span> (<span class='trans2'>Eka</span>) = One ", " <span class='mng'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Muurti</span>) = Form, Image, Embodiment, Personification"]
# # Subword:   शुद्ध (Shuddha) = Pure
# # Subword:   ज्ञान (Jnyaana) = Knowledge
# # Subword:   एक (Eka) = One
# # Subword:   मूर्ति (Muurti) = Form, Image, Embodiment, Personification
# # # get_dic_list: item before subword list nir-malaaya__<span class='mword'>&#x0928;&#x093F;&#x0930;&#x094D;&#x092E;&#x0932;&#x093E;&#x092F;</span> (<span class='trans1'>Nirmalaaya</span>): To the Stainless, Pure <br/> <span class='mng'>&#x0928;&#x093F;&#x0930;&#x094D;&#x092E;&#x0932;</span> (<span class='trans2'>Nirmala</span>) = Stainless, Pure
# ['nir-malaaya', 'निर्मलाय (Nirmalaaya): To the Stainless, Pure ']
# # sub_word_list:  [" <span class='mng'>&#x0928;&#x093F;&#x0930;&#x094D;&#x092E;&#x0932;</span> (<span class='trans2'>Nirmala</span>) = Stainless, Pure"]
# # Subword:   निर्मल (Nirmala) = Stainless, Pure
# # # get_dic_list: item before subword list p-rashaan-taaya__<span class='mword'>&#x092A;&#x094D;&#x0930;&#x0936;&#x093E;&#x0928;&#x094D;&#x0924;&#x093E;&#x092F;</span> (<span class='trans1'>Prashaantaaya</span>): To the Tranquil <br/> <span class='mng'>&#x092A;&#x094D;&#x0930;&#x0936;&#x093E;&#x0928;&#x094D;&#x0924;</span> (<span class='trans2'>Prashaanta</span>) = Calm, Tranquil
# ['p-rashaan-taaya', 'प्रशान्ताय (Prashaantaaya): To the Tranquil ']
# # sub_word_list:  [" <span class='mng'>&#x092A;&#x094D;&#x0930;&#x0936;&#x093E;&#x0928;&#x094D;&#x0924;</span> (<span class='trans2'>Prashaanta</span>) = Calm, Tranquil"]
# # Subword:   प्रशान्त (Prashaanta) = Calm, Tranquil
# # # get_dic_list: item before subword list cid-ghanaaya__<span class='mword'>&#x091A;&#x093F;&#x0926;&#x094D;&#x0918;&#x0928;&#x093E;&#x092F;</span> (<span class='trans1'>Cid-Ghanaaya</span>): To the one Who is as if Consciousness Solidified <br/> <span class='mng'>&#x091A;&#x093F;&#x0924;&#x094D;</span> (<span class='trans2'>Cit</span>) = Consciousness <br/> <span class='mng'>&#x0918;&#x0928;</span> (<span class='trans2'>Ghana</span>) = Compact, Solid, Dense
# ['cid-ghanaaya', 'चिद्घनाय (Cid-Ghanaaya): To the one Who is as if Consciousness Solidified ']
# # sub_word_list:  [" <span class='mng'>&#x091A;&#x093F;&#x0924;&#x094D;</span> (<span class='trans2'>Cit</span>) = Consciousness ", " <span class='mng'>&#x0918;&#x0928;</span> (<span class='trans2'>Ghana</span>) = Compact, Solid, Dense"]
# # Subword:   चित् (Cit) = Consciousness
# # Subword:   घन (Ghana) = Compact, Solid, Dense
# # # get_dic_list: item before subword list maheshaaya__<span class='mword'>&#x092E;&#x0939;&#x0947;&#x0936;&#x093E;&#x092F;</span> (<span class='trans1'>Mahaa-Iishaaya</span>): Who is the Great God <br/> <span class='mng'>&#x092E;&#x0939;&#x093E;</span> (<span class='trans2'>Mahaa</span>) = Great <br/> <span class='mng'>&#x0908;&#x0936;</span> (<span class='trans2'>Iisha</span>) = Lord, God
# ['maheshaaya', 'महेशाय (Mahaa-Iishaaya): Who is the Great God ']
# # sub_word_list:  [" <span class='mng'>&#x092E;&#x0939;&#x093E;</span> (<span class='trans2'>Mahaa</span>) = Great ", " <span class='mng'>&#x0908;&#x0936;</span> (<span class='trans2'>Iisha</span>) = Lord, God"]
# # Subword:   महा (Mahaa) = Great
# # Subword:   ईश (Iisha) = Lord, God
# # # get_dic_list: item before subword list vattamuulanivaasine__<span class='mword'>&#x0935;&#x091F;&#x092E;&#x0942;&#x0932;&#x0928;&#x093F;&#x0935;&#x093E;&#x0938;&#x093F;&#x0928;&#x0947;</span> (<span class='trans1'>Vatta-Muula-Nivaasine</span>): Who dwells at the root <span class='desc'>[i.e. base]</span> of the Banyan Tree <br/> <span class='mng'>&#x0935;&#x091F;</span> (<span class='trans2'>Vatta</span>) = Banyan Tree <br/> <span class='mng'>&#x092E;&#x0942;&#x0932;</span> (<span class='trans2'>Muula</span>) = Root <br/> <span class='mng'>&#x0928;&#x093F;&#x0935;&#x093E;&#x0938;&#x093F;&#x0928;&#x094D;</span> (<span class='trans2'>Nivaasin</span>) = Dwelling
# ['vattamuulanivaasine', 'वटमूलनिवासिने (Vatta-Muula-Nivaasine): Who dwells at the root [i.e. base] of the Banyan Tree ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x091F;</span> (<span class='trans2'>Vatta</span>) = Banyan Tree ", " <span class='mng'>&#x092E;&#x0942;&#x0932;</span> (<span class='trans2'>Muula</span>) = Root ", " <span class='mng'>&#x0928;&#x093F;&#x0935;&#x093E;&#x0938;&#x093F;&#x0928;&#x094D;</span> (<span class='trans2'>Nivaasin</span>) = Dwelling"]
# # Subword:   वट (Vatta) = Banyan Tree
# # Subword:   मूल (Muula) = Root
# # Subword:   निवासिन् (Nivaasin) = Dwelling
# # # get_dic_list: item before subword list sac-cidaanan-daruupaaya__<span class='mword'>&#x0938;&#x091A;&#x094D;&#x091A;&#x093F;&#x0926;&#x093E;&#x0928;&#x0928;&#x094D;&#x0926;&#x0930;&#x0942;&#x092A;&#x093E;&#x092F;</span> (<span class='trans1'>Sac-Cid-Aananda-Ruupaaya</span>): Who is the embodiment of Sacchidananda <span class='desc'>[Existence, Consciousness and Bliss]</span> <br/> <span class='mng'>&#x0938;&#x0924;&#x094D;</span> (<span class='trans2'>Sat</span>) = Existence <br/> <span class='mng'>&#x091A;&#x093F;&#x0924;&#x094D;</span> (<span class='trans2'>Cit</span>) = Consciousness <br/> <span class='mng'>&#x0906;&#x0928;&#x0928;&#x094D;&#x0926;</span> (<span class='trans2'>Aananda</span>) = Bliss <br/> <span class='mng'>&#x0930;&#x0942;&#x092A;</span> (<span class='trans2'>Ruupa</span>) = Form, Embodiment
# ['sac-cidaanan-daruupaaya', 'सच्चिदानन्दरूपाय (Sac-Cid-Aananda-Ruupaaya): Who is the embodiment of Sacchidananda [Existence, Consciousness and Bliss] ']
# # sub_word_list:  [" <span class='mng'>&#x0938;&#x0924;&#x094D;</span> (<span class='trans2'>Sat</span>) = Existence ", " <span class='mng'>&#x091A;&#x093F;&#x0924;&#x094D;</span> (<span class='trans2'>Cit</span>) = Consciousness ", " <span class='mng'>&#x0906;&#x0928;&#x0928;&#x094D;&#x0926;</span> (<span class='trans2'>Aananda</span>) = Bliss ", " <span class='mng'>&#x0930;&#x0942;&#x092A;</span> (<span class='trans2'>Ruupa</span>) = Form, Embodiment"]
# # Subword:   सत् (Sat) = Existence
# # Subword:   चित् (Cit) = Consciousness
# # Subword:   आनन्द (Aananda) = Bliss
# # Subword:   रूप (Ruupa) = Form, Embodiment
# # # get_dic_list: item before subword list ii2sh-varo__<span class='mword'>&#x0908;&#x0936;&#x094D;&#x0935;&#x0930;&#x094B;</span> (<span class='trans1'>Iishvaro</span>): Ishwara <br/> <span class='mng'>&#x0908;&#x0936;&#x094D;&#x0935;&#x0930;</span> (<span class='trans2'>Iishvara</span>) = Ishwara, Gos
# ['ii2sh-varo', 'ईश्वरो (Iishvaro): Ishwara ']
# # sub_word_list:  [" <span class='mng'>&#x0908;&#x0936;&#x094D;&#x0935;&#x0930;</span> (<span class='trans2'>Iishvara</span>) = Ishwara, Gos"]
# # Subword:   ईश्वर (Iishvara) = Ishwara, Gos
# # # get_dic_list: item before subword list gururaat-meti__<span class='mword'>&#x0917;&#x0941;&#x0930;&#x0941;&#x0930;&#x093E;&#x0924;&#x094D;&#x092E;&#x0947;&#x0924;&#x093F;</span> (<span class='trans1'>Gurur-Aatma-Iti</span>): "<span class='desc'>[Ishwara,]</span> Guru and Atman" <br/> <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru <br/> <span class='mng'>&#x0906;&#x0924;&#x094D;&#x092E;&#x0928;&#x094D;</span> (<span class='trans2'>Aatman</span>) = Atman <br/> <span class='mng'>&#x0907;&#x0924;&#x093F;</span> (<span class='trans2'>Iti</span>) = Refers to the words before
# ['gururaat-meti', 'गुरुरात्मेति (Gurur-Aatma-Iti): "[Ishwara,] Guru and Atman" ']
# # sub_word_list:  [" <span class='mng'>&#x0917;&#x0941;&#x0930;&#x0941;</span> (<span class='trans2'>Guru</span>) = Guru ", " <span class='mng'>&#x0906;&#x0924;&#x094D;&#x092E;&#x0928;&#x094D;</span> (<span class='trans2'>Aatman</span>) = Atman ", " <span class='mng'>&#x0907;&#x0924;&#x093F;</span> (<span class='trans2'>Iti</span>) = Refers to the words before"]
# # Subword:   गुरु (Guru) = Guru
# # Subword:   आत्मन् (Aatman) = Atman
# # Subword:   इति (Iti) = Refers to the words before
# # # get_dic_list: item before subword list muur-tibhedavibhaagine__<span class='mword'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;&#x092D;&#x0947;&#x0926;&#x0935;&#x093F;&#x092D;&#x093E;&#x0917;&#x093F;&#x0928;&#x0947;</span> (<span class='trans1'>Muurti-Bheda-Vibhaagine</span>): <span class='desc'>[Ishwara-Guru-Atman]</span> These different forms of <span class='desc'>[apparent]</span> separation <br/> <span class='mng'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Muurti</span>) = Form <br/> <span class='mng'>&#x092D;&#x0947;&#x0926;</span> (<span class='trans2'>Bheda</span>) = Separation, Division <br/> <span class='mng'>&#x0935;&#x093F;&#x092D;&#x093E;&#x0917;</span> (<span class='trans2'>Vibhaaga</span>) = Partition, Division, Separation, Distinction
# ['muur-tibhedavibhaagine', 'मूर्तिभेदविभागिने (Muurti-Bheda-Vibhaagine): [Ishwara-Guru-Atman] These different forms of [apparent] separation ']
# # sub_word_list:  [" <span class='mng'>&#x092E;&#x0942;&#x0930;&#x094D;&#x0924;&#x093F;</span> (<span class='trans2'>Muurti</span>) = Form ", " <span class='mng'>&#x092D;&#x0947;&#x0926;</span> (<span class='trans2'>Bheda</span>) = Separation, Division ", " <span class='mng'>&#x0935;&#x093F;&#x092D;&#x093E;&#x0917;</span> (<span class='trans2'>Vibhaaga</span>) = Partition, Division, Separation, Distinction"]
# # Subword:   मूर्ति (Muurti) = Form
# # Subword:   भेद (Bheda) = Separation, Division
# # Subword:   विभाग (Vibhaaga) = Partition, Division, Separation, Distinction
# # # get_dic_list: item before subword list v-yomavad-__<span class='mword'>&#x0935;&#x094D;&#x092F;&#x094B;&#x092E;&#x0935;&#x0926;&#x094D;</span> (<span class='trans1'>Vyoma-Vad</span>): Like the Sky <span class='desc'>[Chidakasha or Spiritual Sky]</span> <br/> <span class='mng'>&#x0935;&#x094D;&#x092F;&#x094B;&#x092E;&#x0928;&#x094D;</span> (<span class='trans2'>Vyoman</span>) = Sky, here Chidakasha or Spiritual Sky <br/> <span class='mng'>&#x0935;&#x0924;&#x094D;</span> (<span class='trans2'>Vat</span>) = Like
# ['v-yomavad-', 'व्योमवद् (Vyoma-Vad): Like the Sky [Chidakasha or Spiritual Sky] ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x094D;&#x092F;&#x094B;&#x092E;&#x0928;&#x094D;</span> (<span class='trans2'>Vyoman</span>) = Sky, here Chidakasha or Spiritual Sky ", " <span class='mng'>&#x0935;&#x0924;&#x094D;</span> (<span class='trans2'>Vat</span>) = Like"]
# # Subword:   व्योमन् (Vyoman) = Sky, here Chidakasha or Spiritual Sky
# # Subword:   वत् (Vat) = Like
# # # get_dic_list: item before subword list v-yaap-tadehaaya__<span class='mword'>&#x0935;&#x094D;&#x092F;&#x093E;&#x092A;&#x094D;&#x0924;&#x0926;&#x0947;&#x0939;&#x093E;&#x092F;</span> (<span class='trans1'>Vyaapta-Dehaaya</span>): Who pervades <span class='desc'>[like the Spiritual Sky]</span> <br/> <span class='mng'>&#x0935;&#x094D;&#x092F;&#x093E;&#x092A;&#x094D;&#x0924;</span> (<span class='trans2'>Vyaapta</span>) = Pervaded, Spread through, Filled with <br/> <span class='mng'>&#x0926;&#x0947;&#x0939;</span> (<span class='trans2'>Deha</span>) = Body
# ['v-yaap-tadehaaya', 'व्याप्तदेहाय (Vyaapta-Dehaaya): Who pervades [like the Spiritual Sky] ']
# # sub_word_list:  [" <span class='mng'>&#x0935;&#x094D;&#x092F;&#x093E;&#x092A;&#x094D;&#x0924;</span> (<span class='trans2'>Vyaapta</span>) = Pervaded, Spread through, Filled with ", " <span class='mng'>&#x0926;&#x0947;&#x0939;</span> (<span class='trans2'>Deha</span>) = Body"]
# # Subword:   व्याप्त (Vyaapta) = Pervaded, Spread through, Filled with
# # Subword:   देह (Deha) = Body
# ['vish-vam', 'विश्वं (Vishvam): The World, Universe']
# dar-pannadrsh-yamaananagariitul-yam__दर्पणदृश्यमाननगरीतुल्यं (Darpanna-Drshyamaana-Nagarii-Tulyam): The Entire World is Like a City Seen within a Mirror  दर्पण (Darpanna) = Mirror  दृश्य (Drshya) = Visible  नगर (Nagara) = City, Town  तुल्य (Tulya) = Similar, ComparableUniverse is like a reflection in mirror: Master: Man experiences three states of consciousness: waking, dream, and deep sleep. Those who follow the path of knowledge explain away the three states. According to them, Brahman is beyond the three states. It is also beyond the gross, the subtle, and the causal bodies, and beyond the three gunas - sattva, rajas, and tamas. All these are maya, like a reflection in a mirror. The reflection is by no means the real substance. Brahman alone is the Substance and all else is illusory. The knowers of Brahman say, further, that it is the identification of the soul with the body that creates the notion of duality. In that state of identification the reflection appears real. When this identification disappears, a man realizes, 'I am He; I am Brahman.' (From the Gospel of Sri Ramakrishna)
# dar-pannadrsh-yamaananagariitul-yam__दर्पणदृश्यमाननगरीतुल्यं (Darpanna-Drshyamaana-Nagarii-Tulyam): The Entire World is Like a City Seen within a Mirror  दर्पण (Darpanna) = Mirror  दृश्य (Drshya) = Visible  नगर (Nagara) = City, Town  तुल्य (Tulya) = Similar, Comparable
# ...
# 	# subword: {'word': 'iti', 'hindi': ' इति ', 'sandhi': 'Iti'} {'word': 'iti', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Referred to what is said before', 'meaning_idx': 8}
# 	# subword: {'word': 'ābhāti', 'hindi': ' आभाति ', 'sandhi': 'Aabhaati'} {'word': 'ābhāti', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Shining, Blazing', 'meaning_idx': 1}
# # mainword: {'word': 'carācarātmakamidaṁ', 'hindi': 'चराचरात्मकमिदं', 'sandhi': 'Cara-Acara-Aatmakam-Idam', 'subwords': 'cara-acara-ātmaka-idam'} {'word': 'carācarātmakamidaṁ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Moving and Non-Moving', 'meaning_idx': 1}
# 	# subword: {'word': 'cara', 'hindi': ' चर ', 'sandhi': 'Cara'} {'word': 'cara', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Moving', 'meaning_idx': 1}
# 	# subword: {'word': 'acara', 'hindi': ' अचर ', 'sandhi': 'Acara'} {'word': 'acara', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Non-Moving', 'meaning_idx': 1}
# 	# subword: {'word': 'ātmaka', 'hindi': ' आत्मक ', 'sandhi': 'Aatmaka'} {'word': 'ātmaka', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Having the Nature of', 'meaning_idx': 3}
# 	# subword: {'word': 'idam', 'hindi': ' इदम् ', 'sandhi': 'Idam'} {'word': 'idam', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'This'}
# # mainword: {'word': 'mūrtyaṣṭakam', 'hindi': 'मूर्त्यष्टकम्', 'sandhi': 'Muurti-Assttakam', 'subwords': 'mūrti-aṣṭaka'} {'word': 'mūrtyaṣṭakam', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Eight Manifestations', 'meaning_idx': 1}
# 	# subword: {'word': 'mūrti', 'hindi': ' मूर्ति ', 'sandhi': 'Muurti'} {'word': 'mūrti', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Embodiment, Manifestation, Form', 'meaning_idx': 6}
# 	# subword: {'word': 'aṣṭaka', 'hindi': ' अष्टक ', 'sandhi': 'Assttaka'} {'word': 'aṣṭaka', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Consisting of Eight parts', 'meaning_idx': 1}
# # mainword: {'word': 'nānyat', 'hindi': 'नान्यत्', 'sandhi': 'Naanyat', 'subwords': 'na-anya'} {'word': 'nānyat', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'No Other', 'meaning_idx': 1}
# 	# subword: {'word': 'na', 'hindi': ' न ', 'sandhi': 'Na'} {'word': 'na', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Not, No, Nor, Neither', 'meaning_idx': 3}
# 	# subword: {'word': 'anya', 'hindi': ' अन्य ', 'sandhi': 'Anya'} {'word': 'anya', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Other than, Different from', 'meaning_idx': 2}
# # mainword: {'word': 'kiñcana', 'hindi': 'किञ्चन', 'sandhi': 'Kin.cana', 'subwords': 'kiṁcana'} {'word': 'kiñcana', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'In no Way', 'meaning_idx': 2}
# 	# subword: {'word': 'kiṁcana', 'hindi': ' किंचन ', 'sandhi': 'Kimcana'} {'word': 'kiṁcana', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'In no way', 'meaning_idx': 1}
# # mainword: {'word': 'vidyatē', 'hindi': 'विद्यते', 'sandhi': 'Vidyate'} {'word': 'vidyatē', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Exist', 'meaning_idx': 1}
# # mainword: {'word': 'vimr̥śatāṁ', 'hindi': 'विमृशतां', 'sandhi': 'Vimrshataam', 'subwords': 'vimr̥śa'} {'word': 'vimr̥śatāṁ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Reflects', 'meaning_idx': 1}
# 	# subword: {'word': 'vimr̥śa', 'hindi': ' विमृश ', 'sandhi': 'Vimrsha'} {'word': 'vimr̥śa', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Reflection, Consideration, Deliberation', 'meaning_idx': 1}
# # mainword: {'word': 'yasmātparasmādvibhoḥ', 'hindi': 'यस्मात्परस्माद्विभोः', 'sandhi': 'Yasmaat-Parasmaad-Vibhoh', 'subwords': 'yasmāt-parasmāt-vibhū'} {'word': 'yasmātparasmādvibhoḥ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Apart from and Beyond the Being [there cannot exist anything]', 'meaning_idx': 1}
# 	# subword: {'word': 'yasmāt', 'hindi': ' यस्मात् ', 'sandhi': 'Yasmaat'} {'word': 'yasmāt', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'From Which, Cause', 'meaning_idx': 1}
# 	# subword: {'word': 'parasmāt', 'hindi': ' परस्मात् ', 'sandhi': 'Parasmaat'} {'word': 'parasmāt', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Beyond', 'meaning_idx': 1}
# 	# subword: {'word': 'vibhū', 'hindi': ' विभू ', 'sandhi': 'Vibhuu'} {'word': 'vibhū', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Lord, Being Everywhere, Manifestation', 'meaning_idx': 1}
# # mainword: {'word': 'sarvātmatvamiti', 'hindi': 'सर्वात्मत्वमिति', 'sandhi': 'Sarva-Aatmatvam-Iti', 'subwords': 'sarva-ātmatva-iti'} {'word': 'sarvātmatvamiti', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Divine Essence of All', 'meaning_idx': 1}
# 	# subword: {'word': 'sarva', 'hindi': ' सर्व ', 'sandhi': 'Sarva'} {'word': 'sarva', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'All'}
# 	# subword: {'word': 'ātmatva', 'hindi': ' आत्मत्व ', 'sandhi': 'Aatmatva'} {'word': 'ātmatva', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Essence, Spirit', 'meaning_idx': 1}
# 	# subword: {'word': 'iti', 'hindi': ' इति ', 'sandhi': 'Iti'} {'word': 'iti', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'In this manner, Thus', 'meaning_idx': 9}
# # mainword: {'word': 'sphuṭīkr̥tamidaṁ', 'hindi': 'स्फुटीकृतमिदं', 'sandhi': 'Sphuttii-Krtam-Idam', 'subwords': 'sphuṭa-kr̥ta-idam'} {'word': 'sphuṭīkr̥tamidaṁ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Made Clear', 'meaning_idx': 1}
# 	# subword: {'word': 'sphuṭa', 'hindi': ' स्फुट ', 'sandhi': 'Sphutta'} {'word': 'sphuṭa', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Manifest, Evident, Clear', 'meaning_idx': 1}
# 	# subword: {'word': 'kr̥ta', 'hindi': ' कृत ', 'sandhi': 'Krta'} {'word': 'kr̥ta', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Made'}
# 	# subword: {'word': 'idam', 'hindi': ' इदम् ', 'sandhi': 'Idam'} {'word': 'idam', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'This'}
# # mainword: {'word': 'yasmādamuṣmin', 'hindi': 'यस्मादमुष्मिन्', 'sandhi': 'Yasmaad-Amussmin', 'subwords': 'yasmāt-amuṣmin'} {'word': 'yasmādamuṣmin', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': '[The Essence] From Which [Everything Rises is made clear] In This [Hymn]', 'meaning_idx': 1}
# 	# subword: {'word': 'yasmāt', 'hindi': ' यस्मात् ', 'sandhi': 'Yasmaat'} {'word': 'yasmāt', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Since, As, Because', 'meaning_idx': 2}
# 	# subword: {'word': 'amuṣmin', 'hindi': ' अमुष्मिन् ', 'sandhi': 'Amussmin'} {'word': 'amuṣmin', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'In That', 'meaning_idx': 1}
# # mainword: {'word': 'stavē', 'hindi': 'स्तवे', 'sandhi': 'Stave', 'subwords': 'stava'} {'word': 'stavē', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Hymn', 'meaning_idx': 1}
# 	# subword: {'word': 'stava', 'hindi': ' स्तव ', 'sandhi': 'Stava'} {'word': 'stava', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Praise, Eulogy, Hymn', 'meaning_idx': 1}
# # mainword: {'word': 'tēnāsya', 'hindi': 'तेनास्य', 'sandhi': 'Tena-Asya', 'subwords': 'tēna-asya'} {'word': 'tēnāsya', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Hence', 'meaning_idx': 1}
# 	# subword: {'word': 'tēna', 'hindi': ' तेन ', 'sandhi': 'Tena'} {'word': 'tēna', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'On that account, For that reason', 'meaning_idx': 1}
# 	# subword: {'word': 'asya', 'hindi': ' अस्य ', 'sandhi': 'Asya'} {'word': 'asya', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Of It', 'meaning_idx': 1}
# # mainword: {'word': 'śravaṇāttadarthamananāddhyānācca', 'hindi': 'श्रवणात्तदर्थमननाद्ध्यानाच्च', 'sandhi': 'Shravannaat-Tadartha-Mananaad-Dhyaanaac-Ca', 'subwords': 'śravaṇa-tadartha-manana-dhyāna-ca'} {'word': 'śravaṇāttadarthamananāddhyānācca', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'By Listening, Contemplating on its Meaning and Meditating on It', 'meaning_idx': 1}
# 	# subword: {'word': 'śravaṇa', 'hindi': ' श्रवण ', 'sandhi': 'Shravanna'} {'word': 'śravaṇa', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Listening', 'meaning_idx': 1}
# 	# subword: {'word': 'tadartha', 'hindi': ' तदर्थ ', 'sandhi': 'Tadartha'} {'word': 'tadartha', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Its Meaning', 'meaning_idx': 1}
# 	# subword: {'word': 'manana', 'hindi': ' मनन ', 'sandhi': 'Manana'} {'word': 'manana', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Reflection', 'meaning_idx': 1}
# 	# subword: {'word': 'dhyāna', 'hindi': ' ध्यान ', 'sandhi': 'Dhyaana'} {'word': 'dhyāna', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Meditation', 'meaning_idx': 1}
# 	# subword: {'word': 'ca', 'hindi': ' च ', 'sandhi': 'Ca'} {'word': 'ca', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'And'}
# # mainword: {'word': 'saṁkīrtanāt', 'hindi': 'संकीर्तनात्', 'sandhi': 'Samkiirtanaat', 'subwords': 'saṁkīrtana'} {'word': 'saṁkīrtanāt', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'By Praising  It', 'meaning_idx': 1}
# 	# subword: {'word': 'saṁkīrtana', 'hindi': ' संकीर्तन ', 'sandhi': 'Samkiirtana'} {'word': 'saṁkīrtana', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Praise, Glorification', 'meaning_idx': 1}
# # mainword: {'word': 'sarvātmatvamahāvibhūtisahitaṁ', 'hindi': 'सर्वात्मत्वमहाविभूतिसहितं', 'sandhi': 'Sarva-Aatmatva-Mahaa-Vibhuuti-Sahitam', 'subwords': 'sarva-ātmatva-mahā-vibhūti-sahita'} {'word': 'sarvātmatvamahāvibhūtisahitaṁ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': '[One becomes] Endowed with the Knowledge of the Divine Essence present in All', 'meaning_idx': 1}
# 	# subword: {'word': 'sarva', 'hindi': ' सर्व ', 'sandhi': 'Sarva'} {'word': 'sarva', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'All'}
# 	# subword: {'word': 'ātmatva', 'hindi': ' आत्मत्व ', 'sandhi': 'Aatmatva'} {'word': 'ātmatva', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Essence', 'meaning_idx': 2}
# 	# subword: {'word': 'mahā', 'hindi': ' महा ', 'sandhi': 'Mahaa'} {'word': 'mahā', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Great'}
# 	# subword: {'word': 'vibhūti', 'hindi': ' विभूति ', 'sandhi': 'Vibhuuti'} {'word': 'vibhūti', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Greatness', 'meaning_idx': 2}
# 	# subword: {'word': 'sahita', 'hindi': ' सहित ', 'sandhi': 'Sahita'} {'word': 'sahita', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Accompanied by', 'meaning_idx': 1}
# # mainword: {'word': 'syādīśvaratvaṁ', 'hindi': 'स्यादीश्वरत्वं', 'sandhi': 'Syaad-Iishvaratvam', 'subwords': 'syāt-īśvaratva'} {'word': 'syādīśvaratvaṁ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Perhaps the Divine Essence', 'meaning_idx': 1}
# 	# subword: {'word': 'syāt', 'hindi': ' स्यात् ', 'sandhi': 'Syaat'} {'word': 'syāt', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Perhaps', 'meaning_idx': 1}
# 	# subword: {'word': 'īśvaratva', 'hindi': ' ईश्वरत्व ', 'sandhi': 'Iishvaratva'} {'word': 'īśvaratva', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Divine Nature', 'meaning_idx': 1}
# # mainword: {'word': 'svataḥ', 'hindi': 'स्वतः', 'sandhi': 'Svatah'} {'word': 'svataḥ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': "From one's own Self, By Itself", 'meaning_idx': 1}
# # mainword: {'word': 'siddhyēttatpunaraṣṭadhā', 'hindi': 'सिद्ध्येत्तत्पुनरष्टधा', 'sandhi': 'Siddhyet-Tat-Punar-Assttadhaa', 'subwords': 'siddha-tat-punar-aṣṭadhā'} {'word': 'siddhyēttatpunaraṣṭadhā', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Will Awaken Also the Eightfold Manifestations', 'meaning_idx': 1}
# 	# subword: {'word': 'siddha', 'hindi': ' सिद्ध ', 'sandhi': 'Siddha'} {'word': 'siddha', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Accomplished', 'meaning_idx': 1}
# 	# subword: {'word': 'tat', 'hindi': ' तत् ', 'sandhi': 'Tat'} {'word': 'tat', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'That'}
# 	# subword: {'word': 'punar', 'hindi': ' पुनर् ', 'sandhi': 'Punar'} {'word': 'punar', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Again', 'meaning_idx': 1}
# 	# subword: {'word': 'aṣṭadhā', 'hindi': ' अष्टधा ', 'sandhi': 'Assttadhaa'} {'word': 'aṣṭadhā', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Eight-fold', 'meaning_idx': 1}
# # mainword: {'word': 'pariṇataṁ', 'hindi': 'परिणतं', 'sandhi': 'Parinnatam', 'subwords': 'pariṇata'} {'word': 'pariṇataṁ', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Developed', 'meaning_idx': 1}
# 	# subword: {'word': 'pariṇata', 'hindi': ' परिणत ', 'sandhi': 'Parinnata'} {'word': 'pariṇata', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Full-Grown, Developed', 'meaning_idx': 1}
# # mainword: {'word': 'caiśvaryamavyāhatam', 'hindi': 'चैश्वर्यमव्याहतम्', 'sandhi': 'Ca-Aishvaryam-Avyaahatam', 'subwords': 'ca-aiśvaryam-avyāhata'} {'word': 'caiśvaryamavyāhatam', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': '[Eightfold] Divine Powers Unimpeded', 'meaning_idx': 1}
# 	# subword: {'word': 'ca', 'hindi': ' च ', 'sandhi': 'Ca'} {'word': 'ca', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'And'}
# 	# subword: {'word': 'aiśvaryam', 'hindi': ' ऐश्वर्यम् ', 'sandhi': 'Aishvaryam'} {'word': 'aiśvaryam', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Divine Power', 'meaning_idx': 1}
# 	# subword: {'word': 'avyāhata', 'hindi': ' अव्याहत ', 'sandhi': 'Avyaahata'} {'word': 'avyāhata', 'source': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php', 'meaning_value': 'Unresisted, Unimpeded', 'meaning_idx': 1}

# %% [markdown]
# ##### 4th Step: `TODO` Update synonyms col in song table in slokabase.db

# %%
# def get_synonyms_byverse1(mySongs_sql,sloka_no,song_idx,DictonaryWord_sql,DictonaryMeaning_sql):  
#     verse_line_list = mySongs_sql.read_entry(*['sloka_eng'],song_idx=song_idx,slokas_no=sloka_no)[0]['sloka_eng'].split('\n')
#     # print(verse_line_list)
#     if len(verse_line_list)==4:
#         verse_line_list[0] =verse_line_list[0].split('|')[0].strip()
#         verse_line_list[1] =verse_line_list[1].split('|')[0].strip()
#         verse_line_list[2] =verse_line_list[2].split('|')[0].strip()
#         verse_line_list[3] =verse_line_list[3].split('|')[0].strip()
#     elif len(verse_line_list)==2:
#         verse_line_list[0] =verse_line_list[0].split('|')[0].strip()
#         verse_line_list[1] =verse_line_list[1].split('|')[0].strip()        
#     # print(verse_line_list)
#     output = ''
#     for idx,line_idx in enumerate(verse_line_list):
#         # for words in line_idx.split(" "):
#         for word in line_idx.split(" "): #words:
#             # word = words[4]
#             print(f'\t# In line {idx+1}: word={word}')
#             data = DictonaryWord_sql.read_entry(word=word)[0]
#             print(f'\t  # Data in Dict.db word={data["word"]} subword={data["subwords"]}')
#             if isinstance(data['subwords'],str):
#                 for subword in data['subwords'].split('-'):
#                     output += f"""{subword}={DictonaryMeaning_sql.read_entry(word=subword)[0]['meaning_value']}; """
#                     # print(f"""{subword}={DictonaryMeaning_sql.read_entry(word=subword)[0]['meaning_value']};""", end=" ")
#             output += f"""{data['word']}={DictonaryMeaning_sql.read_entry(word=data['word'])[0]['meaning_value']}; """ 
#             # print(f"""{data['word']}={DictonaryMeaning_sql.read_entry(word=data['word'])[0]['meaning_value']};""", end =" ")
#         output= output.strip() + '\n'
#     return output.strip()#)
# # get_synonyms_byverse(mySongs_sql,sloka_no,meta_info['song_idx'])   
# #get_synonyms_byverse(mySongs_sql,12,meta_info['song_idx'])

# %%
SongIndex_sql.read_entry(song_idx=song_idx)[0]#['song_idx']
# Out:
# {'song_idx': 79,
#  'song_name': 'Dakshinamurthy Stotram',
#  'song_short_name': 'DakshinamurthyStotram',
#  'sloka_statues': 1,
#  'division': None,
#  'division_no': 0,
#  'total_slokas': 17,
#  'groups': None,
#  'devotion_god': 'Shiva, Dakshinamurthy',
#  'author': 'Sri Adi Shankaracharya',
#  'describtion': '',
#  'other_links': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php'}

# %%
# meta_info = SongIndex_sql.read_entry(**song_info)[0]#['song_idx']
meta_info = SongIndex_sql.read_entry(song_idx=song_idx)[0]#['song_idx']
print(meta_info)
total_no_verse = meta_info['total_slokas']
for sloka_no in range(1,total_no_verse+1):
    # sloka_no = 1 # 
    print('# Sloka No:',sloka_no)
    if mySongs_sql.read_entry(song_idx=meta_info['song_idx'],slokas_no=sloka_no)[0]['synonyms'] is  None:
        synonyms_by_verse = get_synonyms_byverse(mySongs_sql,sloka_no,meta_info['song_idx'],DictonaryWord_sql,DictonaryMeaning_sql)
        mySongs_sql.update_entry( *['song_idx','slokas_no'],synonyms=synonyms_by_verse, song_idx=meta_info['song_idx'], slokas_no=sloka_no)
# Out:
# {'song_idx': 79, 'song_name': 'Dakshinamurthy Stotram', 'song_short_name': 'DakshinamurthyStotram', 'sloka_statues': 1, 'division': None, 'division_no': 0, 'total_slokas': 17, 'groups': None, 'devotion_god': 'Shiva, Dakshinamurthy', 'author': 'Sri Adi Shankaracharya', 'describtion': '', 'other_links': 'https://greenmesg.org/stotras/shiva/dakshinamurthy_stotram.php'}
# # Sloka No: 1
# 	# In line 1: word=maunavyākhyā
# 	  # Data in Dict.db word=maunavyākhyā subword=mauna-vyākhyā
# 	# In line 1: word=prakaṭita
# 	  # Data in Dict.db word=prakaṭita subword=None
# 	# In line 1: word=parabrahmatattvaṁ
# 	  # Data in Dict.db word=parabrahmatattvaṁ subword=para-brahma-tattva
# 	# In line 1: word=yuvānaṁ
# 	  # Data in Dict.db word=yuvānaṁ subword=yuvan
# 	# In line 2: word=varṣiṣṭhāṁtē
# 	  # Data in Dict.db word=varṣiṣṭhāṁtē subword=varṣiṣṭha-tē
# 	# In line 2: word=vasad
# 	  # Data in Dict.db word=vasad subword=vasa
# 	# In line 2: word=ṛṣigaṇaiḥ
# 	  # Data in Dict.db word=ṛṣigaṇaiḥ subword=ṛṣi-gaṇa
# 	# In line 2: word=āvr̥taṁ
# 	  # Data in Dict.db word=āvr̥taṁ subword=None
# 	# In line 2: word=brahmaniṣṭhaiḥ
# 	  # Data in Dict.db word=brahmaniṣṭhaiḥ subword=brahma-niṣṭha
# 	# In line 3: word=ācāryēndraṁ
# 	  # Data in Dict.db word=ācāryēndraṁ subword=ācārya-indra
# 	# In line 3: word=karakalita
# 	  # Data in Dict.db word=karakalita subword=kara-kalita
# 	# In line 3: word=cinmudramānaṁdamūrtiṁ
# 	  # Data in Dict.db word=cinmudramānaṁdamūrtiṁ subword=cit-mudrā-ānanda-mūrti
# 	# In line 4: word=svātmārāmaṁ
# 	  # Data in Dict.db word=svātmārāmaṁ subword=sva-ātmārāma
# 	# In line 4: word=muditavadanaṁ
# 	  # Data in Dict.db word=muditavadanaṁ subword=mudita-vadana
# 	# In line 4: word=dakṣiṇāmūrtimīḍē
# 	  # Data in Dict.db word=dakṣiṇāmūrtimīḍē subword=dakṣiṇāmūrti-īḍ
# # Sloka No: 2
# 	# In line 1: word=vaṭaviṭapisamīpēbhūmibhāgē
# 	  # Data in Dict.db word=vaṭaviṭapisamīpēbhūmibhāgē subword=vaṭa-viṭapin-samīpa-bhūmi-bhāga
# 	# In line 1: word=niṣaṇṇaṁ
# 	  # Data in Dict.db word=niṣaṇṇaṁ subword=None
# 	# In line 2: word=sakalamunijanānāṁ
# 	  # Data in Dict.db word=sakalamunijanānāṁ subword=sakala-muni-jana
# 	# In line 2: word=jñānadātāramārāt
# 	  # Data in Dict.db word=jñānadātāramārāt subword=jñāna-dātā-ārāt
# 	# In line 3: word=tribhuvanagurumīśaṁ
# 	  # Data in Dict.db word=tribhuvanagurumīśaṁ subword=tri-bhuvana-guru-īśa
# 	# In line 3: word=dakṣiṇāmūrtidēvaṁ
# 	  # Data in Dict.db word=dakṣiṇāmūrtidēvaṁ subword=dakṣiṇāmūrti-dēva
# 	# In line 4: word=jananamaraṇaduḥkhacchēda
# 	  # Data in Dict.db word=jananamaraṇaduḥkhacchēda subword=janana-maraṇa-duḥkha-chēda
# 	# In line 4: word=dakṣaṁ
# 	  # Data in Dict.db word=dakṣaṁ subword=None
# 	# In line 4: word=namāmi
# 	  # Data in Dict.db word=namāmi subword=namas
# # Sloka No: 3
# 	# In line 1: word=citraṁ
# 	  # Data in Dict.db word=citraṁ subword=None
# 	# In line 1: word=vaṭatarormūlē
# 	  # Data in Dict.db word=vaṭatarormūlē subword=vaṭa-taru-mūla
# 	# In line 1: word=vr̥ddhāḥ
# 	  # Data in Dict.db word=vr̥ddhāḥ subword=vr̥ddha
# 	# In line 1: word=śiṣyā
# 	  # Data in Dict.db word=śiṣyā subword=None
# 	# In line 1: word=gururyuvā
# 	  # Data in Dict.db word=gururyuvā subword=guru-yuvan
# 	# In line 2: word=gurostu
# 	  # Data in Dict.db word=gurostu subword=guru-tu
# 	# In line 2: word=maunaṁ
# 	  # Data in Dict.db word=maunaṁ subword=None
# 	# In line 2: word=vyākhyānaṁ
# 	  # Data in Dict.db word=vyākhyānaṁ subword=None
# 	# In line 2: word=śiṣyāstucchinnasaṁśayāḥ
# 	  # Data in Dict.db word=śiṣyāstucchinnasaṁśayāḥ subword=śiṣya-tu-chinna-saṁśaya
# # Sloka No: 4
# 	# In line 1: word=nidhayē
# 	  # Data in Dict.db word=nidhayē subword=nidhi
# 	# In line 1: word=sarvavidyānāṁ
# 	  # Data in Dict.db word=sarvavidyānāṁ subword=sarva-vidyā
# 	# In line 1: word=bhiṣajē
# 	  # Data in Dict.db word=bhiṣajē subword=bhiṣaj
# 	# In line 1: word=bhavarogiṇām
# 	  # Data in Dict.db word=bhavarogiṇām subword=bhava-rogin
# 	# In line 2: word=guravē
# 	  # Data in Dict.db word=guravē subword=guru
# 	# In line 2: word=sarvalokānāṁ
# 	  # Data in Dict.db word=sarvalokānāṁ subword=sarva-loka
# 	# In line 2: word=dakṣiṇāmūrtayē
# 	  # Data in Dict.db word=dakṣiṇāmūrtayē subword=None
# 	# In line 2: word=namaḥ
# 	  # Data in Dict.db word=namaḥ subword=None
# # Sloka No: 5
# 	# In line 1: word=oṁ
# 	  # Data in Dict.db word=oṁ subword=None
# 	# In line 1: word=namaḥ
# 	  # Data in Dict.db word=namaḥ subword=None
# 	# In line 1: word=praṇavārthāya
# 	  # Data in Dict.db word=praṇavārthāya subword=praṇava-artha
# 	# In line 1: word=śuddhajñānaikamūrtayē
# 	  # Data in Dict.db word=śuddhajñānaikamūrtayē subword=śuddha-jñāna-eka-mūrti
# 	# In line 2: word=nirmalāya
# 	  # Data in Dict.db word=nirmalāya subword=nirmala
# 	# In line 2: word=praśāntāya
# 	  # Data in Dict.db word=praśāntāya subword=praśānta
# 	# In line 2: word=dakṣiṇāmūrtayē
# 	  # Data in Dict.db word=dakṣiṇāmūrtayē subword=None
# 	# In line 2: word=namaḥ
# 	  # Data in Dict.db word=namaḥ subword=None
# # Sloka No: 6
# 	# In line 1: word=cidghanāya
# 	  # Data in Dict.db word=cidghanāya subword=cit-ghana
# 	# In line 1: word=mahēśāya
# 	  # Data in Dict.db word=mahēśāya subword=mahā-īśa
# 	# In line 1: word=vaṭamūlanivāsinē
# 	  # Data in Dict.db word=vaṭamūlanivāsinē subword=vaṭa-mūla-nivāsin
# 	# In line 2: word=saccidānandarūpāya
# 	  # Data in Dict.db word=saccidānandarūpāya subword=sat-cit-ānanda-rūpa
# 	# In line 2: word=dakṣiṇāmūrtayē
# 	  # Data in Dict.db word=dakṣiṇāmūrtayē subword=None
# 	# In line 2: word=namaḥ
# 	  # Data in Dict.db word=namaḥ subword=None
# # Sloka No: 7
# 	# In line 1: word=īśvaro
# 	  # Data in Dict.db word=īśvaro subword=īśvara
# 	# In line 1: word=gururātmēti
# 	  # Data in Dict.db word=gururātmēti subword=guru-ātman-iti
# 	# In line 1: word=mūrtibhēdavibhāginē
# 	  # Data in Dict.db word=mūrtibhēdavibhāginē subword=mūrti-bhēda-vibhāga
# 	# In line 2: word=vyomavad
# 	  # Data in Dict.db word=vyomavad subword=vyoman-vat
# 	# In line 2: word=vyāptadēhāya
# 	  # Data in Dict.db word=vyāptadēhāya subword=vyāpta-dēha
# 	# In line 2: word=dakṣiṇāmūrtayē
# 	  # Data in Dict.db word=dakṣiṇāmūrtayē subword=None
# 	# In line 2: word=namaḥ
# 	  # Data in Dict.db word=namaḥ subword=None
# # Sloka No: 8
# 	# In line 1: word=viśvaṁ
# 	  # Data in Dict.db word=viśvaṁ subword=None
# 	# In line 1: word=darpaṇadr̥śyamānanagarītulyaṁ
# 	  # Data in Dict.db word=darpaṇadr̥śyamānanagarītulyaṁ subword=darpaṇa-dr̥śya-nagara-tulya
# 	# In line 1: word=nijāntargataṁ
# 	  # Data in Dict.db word=nijāntargataṁ subword=nija-antargata
# 	# In line 2: word=paśyannātmani
# 	  # Data in Dict.db word=paśyannātmani subword=paśya-ātman
# 	# In line 2: word=māyayā
# 	  # Data in Dict.db word=māyayā subword=māyā
# 	# In line 2: word=bahirivodbhūtaṁ
# 	  # Data in Dict.db word=bahirivodbhūtaṁ subword=bahis-udbhūta
# 	# In line 2: word=yathā
# 	  # Data in Dict.db word=yathā subword=None
# 	# In line 2: word=nidrayā
# 	  # Data in Dict.db word=nidrayā subword=nidrā
# 	# In line 3: word=yaḥ
# 	  # Data in Dict.db word=yaḥ subword=None
# 	# In line 3: word=sākṣātkurutē
# 	  # Data in Dict.db word=sākṣātkurutē subword=sākṣāt-kara
# 	# In line 3: word=prabodhasamayē
# 	  # Data in Dict.db word=prabodhasamayē subword=prabodha-samaya
# 	# In line 3: word=svātmānamēvādvayaṁ
# 	  # Data in Dict.db word=svātmānamēvādvayaṁ subword=sva-ātman-eva-advaya
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 9
# 	# In line 1: word=bījasyā’ntarivāṅkuro
# 	  # Data in Dict.db word=bījasyā’ntarivāṅkuro subword=bīja-antara-iva-aṅkura
# 	# In line 1: word=jagadidaṁ
# 	  # Data in Dict.db word=jagadidaṁ subword=jagat-idam
# 	# In line 1: word=prāṅganirvikalpaṁ
# 	  # Data in Dict.db word=prāṅganirvikalpaṁ subword=prāk-nirvikalpa
# 	# In line 1: word=punaḥ
# 	  # Data in Dict.db word=punaḥ subword=None
# 	# In line 2: word=māyākalpitadēśakālakalanā
# 	  # Data in Dict.db word=māyākalpitadēśakālakalanā subword=māyā-kalpita-dēśa-kāla-kalanā
# 	# In line 2: word=vaicitryacitrīkr̥tam
# 	  # Data in Dict.db word=vaicitryacitrīkr̥tam subword=vaicitrya-citra-kr̥ta
# 	# In line 3: word=māyāvīva
# 	  # Data in Dict.db word=māyāvīva subword=māyāvī-iva
# 	# In line 3: word=vijr̥mbhayatyapi
# 	  # Data in Dict.db word=vijr̥mbhayatyapi subword=vijr̥mbh-api
# 	# In line 3: word=mahāyogīva
# 	  # Data in Dict.db word=mahāyogīva subword=mahā-yogi-iva
# 	# In line 3: word=yaḥ
# 	  # Data in Dict.db word=yaḥ subword=None
# 	# In line 3: word=svēcchayā
# 	  # Data in Dict.db word=svēcchayā subword=sva-icchā
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 10
# 	# In line 1: word=yasyaiva
# 	  # Data in Dict.db word=yasyaiva subword=yasya-eva
# 	# In line 1: word=sphuraṇaṁ
# 	  # Data in Dict.db word=sphuraṇaṁ subword=sphuraṇa
# 	# In line 1: word=sadātmakamasatkalpārthakaṁ
# 	  # Data in Dict.db word=sadātmakamasatkalpārthakaṁ subword=sadā-ātmaka-asat-kalpa-artha
# 	# In line 1: word=bhāsatē
# 	  # Data in Dict.db word=bhāsatē subword=bhāsa
# 	# In line 2: word=sākṣāttattvamasīti
# 	  # Data in Dict.db word=sākṣāttattvamasīti subword=sākṣāt-tat-tvam-asi-iti
# 	# In line 2: word=vēdavacasā
# 	  # Data in Dict.db word=vēdavacasā subword=vēda-vacas
# 	# In line 2: word=yo
# 	  # Data in Dict.db word=yo subword=yaḥ
# 	# In line 2: word=bodhayatyāśritān
# 	  # Data in Dict.db word=bodhayatyāśritān subword=bodha-āśrita
# 	# In line 3: word=yatsākṣātkaraṇādbhavēnna
# 	  # Data in Dict.db word=yatsākṣātkaraṇādbhavēnna subword=yat-sākṣāt-karaṇa-bhava-na
# 	# In line 3: word=punarāvr̥ttirbhavāmbhonidhau
# 	  # Data in Dict.db word=punarāvr̥ttirbhavāmbhonidhau subword=punarāvr̥tti-bhava-bhos-nidhi
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 11
# 	# In line 1: word=nānācchidraghaṭodarasthitamahādīpaprabhā
# 	  # Data in Dict.db word=nānācchidraghaṭodarasthitamahādīpaprabhā subword=nānā-chidra-ghaṭa-udara-sthita-mahā-dīpa-prabhā
# 	# In line 1: word=bhāsvaraṁ
# 	  # Data in Dict.db word=bhāsvaraṁ subword=None
# 	# In line 2: word=jñānaṁ
# 	  # Data in Dict.db word=jñānaṁ subword=None
# 	# In line 2: word=yasya
# 	  # Data in Dict.db word=yasya subword=None
# 	# In line 2: word=tu
# 	  # Data in Dict.db word=tu subword=None
# 	# In line 2: word=cakṣurādikaraṇadvārā
# 	  # Data in Dict.db word=cakṣurādikaraṇadvārā subword=cakṣu-ādi-karaṇa-dvāra
# 	# In line 2: word=vahiḥ
# 	  # Data in Dict.db word=vahiḥ subword=None
# 	# In line 2: word=spandatē
# 	  # Data in Dict.db word=spandatē subword=spanda
# 	# In line 3: word=jānāmīti
# 	  # Data in Dict.db word=jānāmīti subword=jñā-jānāmi-iti
# 	# In line 3: word=tamēva
# 	  # Data in Dict.db word=tamēva subword=tam-eva
# 	# In line 3: word=bhāntamanubhātyētatsamastaṁ
# 	  # Data in Dict.db word=bhāntamanubhātyētatsamastaṁ subword=bhā-anubhā-etad-samasta
# 	# In line 3: word=jagat
# 	  # Data in Dict.db word=jagat subword=None
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 12
# 	# In line 1: word=dēhaṁ
# 	  # Data in Dict.db word=dēhaṁ subword=None
# 	# In line 1: word=prāṇamapīndriyāṇyapi
# 	  # Data in Dict.db word=prāṇamapīndriyāṇyapi subword=prāṇa-api-indriya-api
# 	# In line 1: word=calāṁ
# 	  # Data in Dict.db word=calāṁ subword=cala
# 	# In line 1: word=buddhiṁ
# 	  # Data in Dict.db word=buddhiṁ subword=None
# 	# In line 1: word=ca
# 	  # Data in Dict.db word=ca subword=None
# 	# In line 1: word=śūnyaṁ
# 	  # Data in Dict.db word=śūnyaṁ subword=None
# 	# In line 1: word=viduḥ
# 	  # Data in Dict.db word=viduḥ subword=vid
# 	# In line 2: word=strībālāndhajaḍopamāstvahamiti
# 	  # Data in Dict.db word=strībālāndhajaḍopamāstvahamiti subword=strī-bāla-andha-jaḍa-upama-tu-aham-iti
# 	# In line 2: word=bhrāntā
# 	  # Data in Dict.db word=bhrāntā subword=bhrānta
# 	# In line 2: word=bhr̥śaṁ
# 	  # Data in Dict.db word=bhr̥śaṁ subword=None
# 	# In line 2: word=vādinaḥ
# 	  # Data in Dict.db word=vādinaḥ subword=vādin
# 	# In line 3: word=māyāśaktivilāsakalpitamahāvyāmohasaṁhāriṇē
# 	  # Data in Dict.db word=māyāśaktivilāsakalpitamahāvyāmohasaṁhāriṇē subword=māyā-śakti-vilāsa-kalpita-mahā-vyāmoha-saṁhāra
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 13
# 	# In line 1: word=rāhugrastadivākarēndusadr̥śo
# 	  # Data in Dict.db word=rāhugrastadivākarēndusadr̥śo subword=rāhu-grasta-divākara-indu-sadr̥śa
# 	# In line 1: word=māyāsamācchādanāt
# 	  # Data in Dict.db word=māyāsamācchādanāt subword=māyā-sama-ācchādana
# 	# In line 2: word=sanmātraḥ
# 	  # Data in Dict.db word=sanmātraḥ subword=sat-mātra
# 	# In line 2: word=karaṇopasaṁharaṇato
# 	  # Data in Dict.db word=karaṇopasaṁharaṇato subword=karaṇa-upasaṁhāra
# 	# In line 2: word=yo’bhūtsuṣuptaḥ
# 	  # Data in Dict.db word=yo’bhūtsuṣuptaḥ subword=yaḥ-abhū-suṣupta
# 	# In line 2: word=pumān
# 	  # Data in Dict.db word=pumān subword=None
# 	# In line 3: word=prāgasvāpsamiti
# 	  # Data in Dict.db word=prāgasvāpsamiti subword=prāk-asvāpsam-iti
# 	# In line 3: word=prabodhasamayē
# 	  # Data in Dict.db word=prabodhasamayē subword=prabodha-samaya
# 	# In line 3: word=yaḥ
# 	  # Data in Dict.db word=yaḥ subword=None
# 	# In line 3: word=pratyabhijñāyatē
# 	  # Data in Dict.db word=pratyabhijñāyatē subword=pratyabhijñā
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 14
# 	# In line 1: word=bālyādiṣvapi
# 	  # Data in Dict.db word=bālyādiṣvapi subword=bālya-ādi-api
# 	# In line 1: word=jāgradādiṣu
# 	  # Data in Dict.db word=jāgradādiṣu subword=jāgrata-ādi
# 	# In line 1: word=tathā
# 	  # Data in Dict.db word=tathā subword=None
# 	# In line 1: word=sarvāsvavasthāsvapi
# 	  # Data in Dict.db word=sarvāsvavasthāsvapi subword=sarva-avasthā-api
# 	# In line 2: word=vyāvr̥ttāsvanuvartamānamahamityantaḥ
# 	  # Data in Dict.db word=vyāvr̥ttāsvanuvartamānamahamityantaḥ subword=vyāvr̥tta-anu-vartamāna-aham-iti-anta
# 	# In line 2: word=sphurantaṁ
# 	  # Data in Dict.db word=sphurantaṁ subword=sphur
# 	# In line 2: word=sadā
# 	  # Data in Dict.db word=sadā subword=None
# 	# In line 3: word=svātmānaṁ
# 	  # Data in Dict.db word=svātmānaṁ subword=sva-ātman
# 	# In line 3: word=prakaṭīkaroti
# 	  # Data in Dict.db word=prakaṭīkaroti subword=prakaṭa-kara
# 	# In line 3: word=bhajatāṁ
# 	  # Data in Dict.db word=bhajatāṁ subword=bhaj
# 	# In line 3: word=yo
# 	  # Data in Dict.db word=yo subword=yaḥ
# 	# In line 3: word=mudrayābhadrayā
# 	  # Data in Dict.db word=mudrayābhadrayā subword=mudrā-bhadra
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 15
# 	# In line 1: word=viśvaṁ
# 	  # Data in Dict.db word=viśvaṁ subword=None
# 	# In line 1: word=paśyati
# 	  # Data in Dict.db word=paśyati subword=paśya
# 	# In line 1: word=kāryakāraṇatayā
# 	  # Data in Dict.db word=kāryakāraṇatayā subword=kāryakāraṇa-tayā
# 	# In line 1: word=svasvāmisambandhataḥ
# 	  # Data in Dict.db word=svasvāmisambandhataḥ subword=svasvāmi-sambandha
# 	# In line 2: word=śiṣyācāryatayā
# 	  # Data in Dict.db word=śiṣyācāryatayā subword=śiṣya-ācārya-tayā
# 	# In line 2: word=tathaiva
# 	  # Data in Dict.db word=tathaiva subword=tathā-eva
# 	# In line 2: word=pitr̥putrādyātmanā
# 	  # Data in Dict.db word=pitr̥putrādyātmanā subword=pitā-putra-ādi-ātman
# 	# In line 2: word=bhēdataḥ
# 	  # Data in Dict.db word=bhēdataḥ subword=bhēda
# 	# In line 3: word=svapnē
# 	  # Data in Dict.db word=svapnē subword=svapna
# 	# In line 3: word=jāgrati
# 	  # Data in Dict.db word=jāgrati subword=jāgrat
# 	# In line 3: word=vā
# 	  # Data in Dict.db word=vā subword=None
# 	# In line 3: word=ya
# 	  # Data in Dict.db word=ya subword=None
# 	# In line 3: word=eṣa
# 	  # Data in Dict.db word=eṣa subword=None
# 	# In line 3: word=puruṣo
# 	  # Data in Dict.db word=puruṣo subword=puruṣa
# 	# In line 3: word=māyāparibhrāmitaḥ
# 	  # Data in Dict.db word=māyāparibhrāmitaḥ subword=māyā-paribhrama
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 16
# 	# In line 1: word=bhūrambhāṁsyanalo’nilo’mbaramaharnātho
# 	  # Data in Dict.db word=bhūrambhāṁsyanalo’nilo’mbaramaharnātho subword=bhū-ambhas-anala-anila-ambara-aharnātha
# 	# In line 1: word=himāṁśu
# 	  # Data in Dict.db word=himāṁśu subword=None
# 	# In line 1: word=pumān
# 	  # Data in Dict.db word=pumān subword=None
# 	# In line 2: word=ityābhāti
# 	  # Data in Dict.db word=ityābhāti subword=iti-ābhāti
# 	# In line 2: word=carācarātmakamidaṁ
# 	  # Data in Dict.db word=carācarātmakamidaṁ subword=cara-acara-ātmaka-idam
# 	# In line 2: word=yasyaiva
# 	  # Data in Dict.db word=yasyaiva subword=yasya-eva
# 	# In line 2: word=mūrtyaṣṭakam
# 	  # Data in Dict.db word=mūrtyaṣṭakam subword=mūrti-aṣṭaka
# 	# In line 3: word=nānyat
# 	  # Data in Dict.db word=nānyat subword=na-anya
# 	# In line 3: word=kiñcana
# 	  # Data in Dict.db word=kiñcana subword=kiṁcana
# 	# In line 3: word=vidyatē
# 	  # Data in Dict.db word=vidyatē subword=None
# 	# In line 3: word=vimr̥śatāṁ
# 	  # Data in Dict.db word=vimr̥śatāṁ subword=vimr̥śa
# 	# In line 3: word=yasmātparasmādvibhoḥ
# 	  # Data in Dict.db word=yasmātparasmādvibhoḥ subword=yasmāt-parasmāt-vibhū
# 	# In line 4: word=tasmai
# 	  # Data in Dict.db word=tasmai subword=None
# 	# In line 4: word=śrīgurumūrtayē
# 	  # Data in Dict.db word=śrīgurumūrtayē subword=śrī-guru-mūrta
# 	# In line 4: word=nama
# 	  # Data in Dict.db word=nama subword=namas
# 	# In line 4: word=idaṁ
# 	  # Data in Dict.db word=idaṁ subword=None
# 	# In line 4: word=śrīdakṣiṇāmūrtayē
# 	  # Data in Dict.db word=śrīdakṣiṇāmūrtayē subword=śrī-dakṣiṇāmūrti
# # Sloka No: 17
# 	# In line 1: word=sarvātmatvamiti
# 	  # Data in Dict.db word=sarvātmatvamiti subword=sarva-ātmatva-iti
# 	# In line 1: word=sphuṭīkr̥tamidaṁ
# 	  # Data in Dict.db word=sphuṭīkr̥tamidaṁ subword=sphuṭa-kr̥ta-idam
# 	# In line 1: word=yasmādamuṣmin
# 	  # Data in Dict.db word=yasmādamuṣmin subword=yasmāt-amuṣmin
# 	# In line 1: word=stavē
# 	  # Data in Dict.db word=stavē subword=stava
# 	# In line 2: word=tēnāsya
# 	  # Data in Dict.db word=tēnāsya subword=tēna-asya
# 	# In line 2: word=śravaṇāttadarthamananāddhyānācca
# 	  # Data in Dict.db word=śravaṇāttadarthamananāddhyānācca subword=śravaṇa-tadartha-manana-dhyāna-ca
# 	# In line 2: word=saṁkīrtanāt
# 	  # Data in Dict.db word=saṁkīrtanāt subword=saṁkīrtana
# 	# In line 3: word=sarvātmatvamahāvibhūtisahitaṁ
# 	  # Data in Dict.db word=sarvātmatvamahāvibhūtisahitaṁ subword=sarva-ātmatva-mahā-vibhūti-sahita
# 	# In line 3: word=syādīśvaratvaṁ
# 	  # Data in Dict.db word=syādīśvaratvaṁ subword=syāt-īśvaratva
# 	# In line 3: word=svataḥ
# 	  # Data in Dict.db word=svataḥ subword=None
# 	# In line 4: word=siddhyēttatpunaraṣṭadhā
# 	  # Data in Dict.db word=siddhyēttatpunaraṣṭadhā subword=siddha-tat-punar-aṣṭadhā
# 	# In line 4: word=pariṇataṁ
# 	  # Data in Dict.db word=pariṇataṁ subword=pariṇata
# 	# In line 4: word=caiśvaryamavyāhatam
# 	  # Data in Dict.db word=caiśvaryamavyāhatam subword=ca-aiśvaryam-avyāhata

# %%
# mysong_index =79
# mySongs_sql.delete_entry(song_idx=mysong_index) # delete all verse or sloka
# SongIndex_sql.delete_entry(song_idx=mysong_index) # delete in index table
# Out:
# DELETE FROM Songs WHERE song_idx=79;
# DELETE FROM SongIndex WHERE song_idx=79;

# %%
# mySongs_sql.update_entry(*['song_idx'], synonyms='NULL' ,song_idx=79)
# # mySongs.update_entry( *['song_idx','slokas_no'],sloka_hindi='test', song_idx=2, slokas_no=1)
# # UPDATE temp SET  sloka_hindi='test' WHERE  song_idx=2 and  slokas_no=1
# Out:
# Exception: database is locked
