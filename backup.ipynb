# %%
from slokabase.SqliteModel import get_create_table_query, get_insert_query, get_read_query, get_update_query, get_delete_query
from slokabase.SqliteModel import SqliteModel

# %%
import os, sqlite3 
# db_name = 'slokabase_10.db'
db_name = 'slokabase.db'
db_path = os.path.join(os.getcwd(),db_name)

# %%
SongIndex_sql = SqliteModel(db_path,'SongIndex')
mySongs_sql = SqliteModel(db_path,'Songs')

# %%
# Create Table if Not Created  and add song as showen in 02_AddNewSong.ipynb
    # The Song List should not be empty if not we can't export the file

# %% [markdown]
# ## Add Song Info to Database

# %%
# get seleted song by 'song_idx' 
mysong_index =1

# %%
# Get Song Info 
songIdx_info = SongIndex_sql.read_entry(song_idx=mysong_index)[0]
songIdx_info
# mysong_name = SongIndex_sql.read_entry(*['song_name'],song_idx=5)[0]['song_name'].replace(" ","")
# Out:
# {'song_idx': 1,
#  'song_name': 'Śri Daśavātāra Stotraṁ',
#  'song_short_name': 'ŚriDaśavātāraStotraṁ',
#  'sloka_statues': 1,
#  'division': None,
#  'division_no': 0,
#  'total_slokas': None,
#  'groups': None,
#  'devotion_god': None,
#  'author': 'Jayadeva Goswami',
#  'describtion': 'some',
#  'other_links': 'http://kksongs.org/songs/p/pralayapayodhijale.html <br>\nhttp://kksongs.org/synonym/p/pralayapayodhijale.html'}

# %%
backup_dir = 'SlokaBackUp'
if not os.path.exists(backup_dir):
   os.makedirs(backup_dir)

# file_name = 'test_copy.txt'
# file_path = os.path.join(backup_dir,file_name)

# file_path = 'Lyrics/test_copy.txt'

mysong_idx = 4
# song_type = 'sloka_eng'
# song_type = 'synonyms'
song_type = 'translation'

def write_song(file_path, song_type, mySongs_sql, mysong_idx):
    start_sloka_no=0
    buffer = []
    for line in mySongs_sql.read_entry(*[song_type,'slokas_no'],song_idx=mysong_idx):
        if line[song_type] != None:
            buffer.append(line[song_type])
            if start_sloka_no != line['slokas_no']:
                buffer.append('\n\n')
            start_sloka_no = line['slokas_no']

    if len(buffer) !=0:
            del buffer[-1]
    # print(buffer)
    # print(''.join(buffer))
    with open(file_path, 'w') as wf:
        wf.write(''.join(buffer))
        
# write_song(file_path, song_type, mySongs_sql,mysong_idx)
# write_song(file_path, 'synonyms', mySongs_sql,3)

# %%
# mysong_idx = 1 # Sri Dashavatara Stotram
mysong_idx =4 # Radhika Astakam

songIdx_info = SongIndex_sql.read_entry(song_idx=mysong_idx)[0]
print(songIdx_info)
mysong_name = songIdx_info['song_name'].replace(" ","")



# manual_idx = None
manual_idx = 2 # For Radhika Astakam
song_type = ['sloka_eng', 'synonyms','translation']

for type in song_type: 
    if manual_idx:
        file_path = f'Lyrics/{manual_idx:02}-{mysong_name}-{type}.txt'
    else:
        file_path = f'Lyrics/{mysong_idx:02}-{mysong_name}-{type}.txt'
    print(file_path,type)
    write_song(file_path, type, mySongs_sql,mysong_idx)

import json     
if manual_idx:
    file_path = f'Lyrics/{manual_idx:02}-{mysong_name}-info.json'
else:
    file_path = f'Lyrics/{mysong_idx:02}-{mysong_name}-info.json'

# file_path = f'Lyrics/{mysong_idx:02}-{mysong_name}-info.json'
with open(file_path, "w") as wjson:
    json.dump(songIdx_info, wjson)
print(file_path)
# Out:
# {'song_idx': 4, 'song_name': 'Radhika Astakam', 'song_short_name': 'radastk', 'sloka_statues': 1, 'division': None, 'division_no': 0, 'total_slokas': None, 'groups': None, 'devotion_god': None, 'author': 'Krishnadasa Kaviraja Goswami', 'describtion': None, 'other_links': 'Sankrit Dictionary:\nhttps://www.learnsanskrit.cc/translate\nhttps://vedabase.io/en/search/synonyms/\n\nLyrics : \nhttp://kksongs.org/songs/k/kunkumaktakancanabja.html\n\nYoutuve Video \nhttps://www.youtube.com/watch?v=ZBk4MLiWIc8\nhttps://www.youtube.com/watch?v=nIGuUCKjxP0&t=47s\nhttps://www.youtube.com/watch?v=tdx1KybTnpE\nhttps://www.youtube.com/watch?v=-54D7Y1Qis0\n'}
# Lyrics/02-RadhikaAstakam-sloka_eng.txt sloka_eng
# Lyrics/02-RadhikaAstakam-synonyms.txt synonyms
# Lyrics/02-RadhikaAstakam-translation.txt translation
# Lyrics/02-RadhikaAstakam-info.json

# %%
mysong_idx =1

# %%
f'Lyrics/{mysong_idx:04}'
# Out:
# 'Lyrics/0001'

# %%
backup_dir = 'SlokaBackUp'
# SongIndex_sql.read_entry(*['song_idx'])

# %%
import json

backup_dir = 'SlokaBackUp'
if not os.path.exists(backup_dir):
   os.makedirs(backup_dir)

# songIdx_info
index_list = []
for idx_dic in SongIndex_sql.read_entry(*['song_idx']):
    # print(idx_dic['song_idx'])
    index_list.append(idx_dic['song_idx'])
index_list.sort()

for song_idx in index_list:
# song_idx = 1
    songIdx_info = SongIndex_sql.read_entry(song_idx=song_idx)[0]
    song_name = songIdx_info['song_name'].replace(" ","")
    song_type = ['sloka_eng', 'synonyms','translation']

    for s_type in song_type:
        file_name = f'{song_idx:04}-{song_name}-{s_type}.txt'
        file_path = os.path.join(backup_dir,file_name)
        write_song(file_path, s_type, mySongs_sql,song_idx)
        print(file_path)

    file_name = f'{song_idx:04}-{song_name}-info.json'
    file_path = os.path.join(backup_dir,file_name)
    with open(file_path, "w") as wjson:
        json.dump(songIdx_info, wjson)
    print(file_path)
# Out:
# SlokaBackUp/0001-ŚriDaśavātāraStotraṁ-sloka_eng.txt
# SlokaBackUp/0001-ŚriDaśavātāraStotraṁ-synonyms.txt
# SlokaBackUp/0001-ŚriDaśavātāraStotraṁ-translation.txt
# SlokaBackUp/0001-ŚriDaśavātāraStotraṁ-info.json
# SlokaBackUp/0002-ŚriRādhikāAṣṭakam-sloka_eng.txt
# SlokaBackUp/0002-ŚriRādhikāAṣṭakam-synonyms.txt
# SlokaBackUp/0002-ŚriRādhikāAṣṭakam-translation.txt
# SlokaBackUp/0002-ŚriRādhikāAṣṭakam-info.json
# SlokaBackUp/0003-ŚrīGovindaDāmodaraStotram-sloka_eng.txt
# SlokaBackUp/0003-ŚrīGovindaDāmodaraStotram-synonyms.txt
# SlokaBackUp/0003-ŚrīGovindaDāmodaraStotram-translation.txt
# SlokaBackUp/0003-ŚrīGovindaDāmodaraStotram-info.json
# SlokaBackUp/0004-ŚriNarasimhaKavacaṁStotraṁ-sloka_eng.txt
# SlokaBackUp/0004-ŚriNarasimhaKavacaṁStotraṁ-synonyms.txt
# SlokaBackUp/0004-ŚriNarasimhaKavacaṁStotraṁ-translation.txt
# SlokaBackUp/0063-VrndavanaRamyaSthana-translation.txt
# SlokaBackUp/0063-VrndavanaRamyaSthana-info.json
# SlokaBackUp/0064-YasomatiNandana-sloka_eng.txt
# SlokaBackUp/0064-YasomatiNandana-synonyms.txt
# SlokaBackUp/0064-YasomatiNandana-translation.txt
# SlokaBackUp/0064-YasomatiNandana-info.json
# SlokaBackUp/0065-KabeGauraVane-sloka_eng.txt
# SlokaBackUp/0065-KabeGauraVane-synonyms.txt
# SlokaBackUp/0065-KabeGauraVane-translation.txt
# SlokaBackUp/0065-KabeGauraVane-info.json
# SlokaBackUp/0066-KabeHa’beBolo-sloka_eng.txt
# SlokaBackUp/0066-KabeHa’beBolo-synonyms.txt
# SlokaBackUp/0066-KabeHa’beBolo-translation.txt
# SlokaBackUp/0066-KabeHa’beBolo-info.json
# SlokaBackUp/0067-KrsnaHoiteCaturmukha-sloka_eng.txt
# SlokaBackUp/0067-KrsnaHoiteCaturmukha-synonyms.txt
# SlokaBackUp/0067-KrsnaHoiteCaturmukha-translation.txt
# SlokaBackUp/0067-KrsnaHoiteCaturmukha-info.json
# SlokaBackUp/0068-KrsnotkirtanaGanaNartana(SriSadgosvamyastakam)-sloka_eng.txt
# SlokaBackUp/0068-KrsnotkirtanaGanaNartana(SriSadgosvamyastakam)-synonyms.txt
# SlokaBackUp/0068-KrsnotkirtanaGanaNartana(SriSadgosvamyastakam)-translation.txt
# SlokaBackUp/0068-KrsnotkirtanaGanaNartana(SriSadgosvamyastakam)-info.json
# SlokaBackUp/0069-NamoNamahTulasiKrsnaPreyasi(I)-sloka_eng.txt
# SlokaBackUp/0069-NamoNamahTulasiKrsnaPreyasi(I)-synonyms.txt
# SlokaBackUp/0069-NamoNamahTulasiKrsnaPreyasi(I)-translation.txt
# SlokaBackUp/0069-NamoNamahTulasiKrsnaPreyasi(I)-info.json
# SlokaBackUp/0070-NamoNamahTulasiMaharani(SriTulasiArotik)-sloka_eng.txt
# SlokaBackUp/0070-NamoNamahTulasiMaharani(SriTulasiArotik)-synonyms.txt
# SlokaBackUp/0070-NamoNamahTulasiMaharani(SriTulasiArotik)-translation.txt
# SlokaBackUp/0070-NamoNamahTulasiMaharani(SriTulasiArotik)-info.json
# SlokaBackUp/0071-Nitaipadakamala-sloka_eng.txt
# SlokaBackUp/0071-Nitaipadakamala-synonyms.txt
# SlokaBackUp/0071-Nitaipadakamala-translation.txt
# SlokaBackUp/0071-Nitaipadakamala-info.json
# SlokaBackUp/0072-MahiṣāsuraMardiniStotram-sloka_eng.txt
# SlokaBackUp/0072-MahiṣāsuraMardiniStotram-synonyms.txt
# SlokaBackUp/0072-MahiṣāsuraMardiniStotram-translation.txt
# SlokaBackUp/0072-MahiṣāsuraMardiniStotram-info.json
# SlokaBackUp/0073-MyDasavataraStotram10-sloka_eng.txt
# SlokaBackUp/0073-MyDasavataraStotram10-synonyms.txt
# SlokaBackUp/0073-MyDasavataraStotram10-translation.txt
# SlokaBackUp/0073-MyDasavataraStotram10-info.json

# %%
import pandas as pd 
data = SongIndex_sql.read_entry()
df = pd.DataFrame(data)
file_path = os.path.join(backup_dir,'index.csv')
df.to_csv(file_path,index=False)
